# %% [markdown]
# # Seq2Seq: Encoder-Decoder Chatbot

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/2560/1*1I2tTjCkMHlQ-r73eRn4ZQ.png)

# %%
import numpy as np
import pandas as pd
import string
import pickle
import operator
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Step 1. Import Data

# %%
# .txtから会話データを取得する
import codecs

with codecs.open("movie_lines.txt", "rb", encoding="utf-8", errors="ignore") as f:
    lines = f.read().split("\n")
    conversations = []
    for line in lines:
        data = line.split(" +++$+++ ")
        conversations.append(data)

# %%
conversations[:6]
# Out:
# [['L1045', 'u0', 'm0', 'BIANCA', 'They do not!'],
#  ['L1044', 'u2', 'm0', 'CAMERON', 'They do to!'],
#  ['L985', 'u0', 'm0', 'BIANCA', 'I hope so.'],
#  ['L984', 'u2', 'm0', 'CAMERON', 'She okay?'],
#  ['L925', 'u0', 'm0', 'BIANCA', "Let's go."],
#  ['L924', 'u2', 'm0', 'CAMERON', 'Wow']]

# %%
# idと会話だけ取り出す
chats = {}
for tokens in conversations:
    if len(tokens) > 4:
        idx = tokens[0][1:]
        chat = tokens[4]
        chats[int(idx)] = chat

# %%
chats
# Out:
# {524288: 'You bastards!!',
#  524293: "I knew this would happen! Those bastard Canadians have now killed a child! Can't people see the damage that film is doing?!",
#  524294: 'He was killed doing something he saw in the movie. It was Terrance and Phillip... THEY killed Kenny.',
#  524295: 'You bastards.',
#  524296: "This is it! The time for action is NOW!!  <b>Something must be done! This is like a spreading rash! They're pulling out our children's brains and filling them with trash! Can't you see what this is leading to? A world of smut and sex and poo! I believe the good fight has begun! Something must be done!</b>",
#  524308: "I bet him he couldn't do it... I bet him a hundred dollars!",
#  524309: "Come on, Cartman. It's not your fault.",
#  524310: "No, I know. I'm just fucking STOKED I don't have to pay him!",
#  524311: 'Oh.',
#  524312: "I can't believe he's dead.",
#  524313: "Yeah, I'm having total deja vu right now. Like this has all happened before...",
#  524315: 'How can they do this?',
#  524316: "It isn't fair!",
#  87387: 'Yakuza.',
#  524324: 'Hello, Conan!',
#  524325: 'Hello, Brooke Shields!',
#  87388: 'Good.  Very good...',
#  524332: 'Good one, Phillip!  Cheers.',
#  524333: 'Cheers, Terrance!',
#  49: 'Did you change your hair?',
#  50: 'No.',
#  51: 'You might wanna think about it',
#  628487: "Apparently I'm not as dumb as you thought I am.",
#  524343: 'Terrance and Phillip, you are under arrest for working in America without the proper documents! WE GOT YOU!',
#  524344: 'Dude, what the hell is going on?',
#  524345: "Phillip, we've been tricked and ambushed by The Conan O'Brian Show!!",
#  524346: 'This little scrotum sucker willfully deceived us!  You are a bad man!',
#  59: 'I missed you.',
#  60: 'It says here you exposed yourself to a group of freshmen girls.',
#  61: 'It was a bratwurst.  I was eating lunch.',
#  62: 'With the teeth of your zipper?',
#  63: 'You the new guy?',
#  64: 'So they tell me...',
#  65: "C'mon.  I'm supposed to give you the tour.",
#  66: 'So -- which Dakota you from?',
#  67: "North, actually.  How'd you   ?",
#  68: 'I was kidding. People actually live there?',
#  69: "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  70: 'How many people were in your old school?',
#  71: 'Thirty-two.',
#  72: 'Get out!',
#  73: 'How many people go here?',
#  74: 'Couple thousand. Most of them evil',
#  77: "That I'm used to.",
#  78: 'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  611683: 'Ray --',
#  524372: 'Who the hell made up that law?!',
#  524373: "You can't do this!! Have you ever HAD Cheesy Poofs? They're a taste sensation with a delightful cheddar crunch.",
#  87: 'That girl -- I --',
#  88: 'You burn, you pine, you perish?',
#  89: 'Who is she?',
#  90: "Bianca Stratford.  Sophomore. Don't even think about it",
#  91: 'Why not?',
#  92: "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  524381: 'We already know what you did. We saw it on television.',
#  611685: "What'd you expect to hear?",
#  524384: "But they fucking didn't do anything wrong!",
#  524385: 'Yeah!  And what rim job expert went and outlawed Cheesy Poofs!?',
#  524386: 'What was that word, young man!?',
#  524387: "Oh, he said rim job.  It's when someone licks your ass for-",
#  524388: 'I know what it is!',
#  87398: 'You can trust me.',
#  103: "Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#  104: 'Expressing my opinion is not a terrorist action.',
#  105: "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  106: 'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  107: 'The point is Kat -- people perceive you as somewhat ...',
#  108: 'Tempestuous?',
#  109: 'No ... I believe "heinous bitch" is the term used most often.',
#  524400: 'MMMMMPHPHPHPHP!!!!!',
#  524401: 'Fallen one... We have such sights to show you!',
#  524402: 'I am Satan. I am your God, now.',
#  524403: 'MPH RM!!!',
#  524406: 'Oh, a new recruit, huh? Welcome to hell, kid! Relax! Take a load off!!',
#  524407: "You remember... Saddam Hussein, don't you?!",
#  123: "Who's that?",
#  124: 'Patrick Verona   Random skid.',
#  125: "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  126: "I'm sure he's completely incapable of doing anything that interesting.",
#  127: 'He always look so',
#  128: 'Block E?',
#  129: 'Mandella, eat.  Starving yourself is a very slow way to die.',
#  130: 'Just a little.',
#  131: "What's this?",
#  132: 'An attempted slit.',
#  133: "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  134: "But imagine the things he'd say during sex.",
#  558663: 'Too late, Luthor. Too late . . .',
#  139: 'Why do girls like that always like guys like that?',
#  140: "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  141: 'He always have that shit-eating grin?',
#  142: "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  143: 'You know French?',
#  144: "Sure do ... my Mom's from Canada",
#  145: 'Guess who just signed up for a tutor?',
#  146: "You mean I'd get a chance to talk to her?",
#  147: 'You could consecrate with her, my friend.',
#  148: "The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  149: 'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  150: "They're running the rest of me next month.",
#  151: 'The people at this school are so incredibly foul.',
#  152: "You could always go with me.  I'm sure William has some friends.",
#  524444: 'Fight the power!',
#  157: 'Yeah, just a minor encounter with the shrew.',
#  158: "That's her?  Bianca's sister?",
#  159: 'The mewling, rampalian wretch herself.',
#  161: 'In the microwave.',
#  162: 'Make anyone cry today?',
#  524451: "The problem is you don't allow your children to think for themselves. You try to raise them in a protective bubble, and then when they finally get old enough, they realize they've been lied to, and they resent you for it.",
#  164: "Where've you been?",
#  165: 'Nowhere... Hi, Daddy.',
#  558664: "Listen. Have I got a proposition for you, Superman. I mean I owe you one, you know? Now don't say yes or no till you hear me out . . .",
#  170: "What's a synonym for throbbing?",
#  171: 'Sarah Lawrence is on the other side of the country.',
#  172: 'I know.',
#  173: 'I thought we decided you were going to school here.  At U of 0.',
#  174: 'You decided.',
#  179: "Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  180: "No! You're not dating until your sister starts dating.  End of discussion.",
#  181: 'What if she never starts dating?',
#  182: "Then neither will you.  And I'll get to sleep at night.",
#  183: "But it's not fair -- she's a mutant, Daddy!",
#  184: 'This from someone whose diary is devoted to favorite grooming tips?',
#  185: 'Enough!',
#  189: "But she doesn't want to date.",
#  190: 'Exactly my point',
#  191: 'Jesus!  Can a man even grab a sandwich before you women start dilating?',
#  192: 'Tumescent!',
#  193: "You're not helping.",
#  194: 'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  195: "Well, I thought we'd start with pronunciation, if that's okay with you.",
#  196: 'Not the hacking and gagging and spitting part.  Please.',
#  197: "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  198: "You're asking me out.  That's so cute. What's your name again?",
#  199: 'Forget it.',
#  200: "No, no, it's my fault -- we didn't have a proper introduction ---",
#  201: 'Cameron.',
#  202: "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  203: 'Seems like she could get a date easy enough...',
#  204: 'Why?',
#  205: 'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  206: "That's a shame.",
#  207: 'Gosh, if only we could find Kat a boyfriend...',
#  208: 'Let me see what I can do.',
#  524497: "Alright, I'll make the call...",
#  210: 'I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  211: "Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  212: 'What about him?',
#  213: 'You wanna go out with him?',
#  215: "What makes you think he'll do it?",
#  216: 'He seems like he thrives on danger',
#  217: "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  218: 'They always let felons sit in on Honors Biology?',
#  219: "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  220: "Forget his reputation.  Do you think we've got a plan or not?",
#  221: "Did she actually say she'd go out with you?",
#  222: "That's what I just said",
#  223: "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  224: 'I thought you hated those people.',
#  225: "Hey -- I've gotta have a few clients when I get to Wall Street.",
#  524514: 'Yeah!',
#  524515: 'This is about freedom of speech, Stan, about censorship.',
#  558666: "Wait a minute, wait a minute, let's talk a deal, Superman. We can take a lunch on this --",
#  524517: 'What the hell are you talking about, kid?',
#  524518: "You don't get it Stan... You just don't get it.",
#  231: 'Hey.',
#  232: 'Are you lost?',
#  233: 'Nope - just came by to chat',
#  234: "We don't chat.",
#  235: "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  236: "We're not.",
#  524525: 'Thank God, that sucked ass.',
#  238: "But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  239: 'Does this conversation have a purpose?',
#  240: "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  524529: 'Oh yeah.',
#  524530: 'The rest of you are graduated. You can go home today.',
#  663415: "Sorry, it's this thing with Blake.  I mean, you don't really think anyone's out to get us -- do you?",
#  244: 'You got him involved?',
#  245: "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  247: 'So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  248: 'William would never have gone to a state school.',
#  249: "William didn't even go to high school",
#  250: "That's never been proven",
#  251: 'Neither has his heterosexuality.',
#  252: "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  253: 'Does it matter?',
#  254: 'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  524544: "Hey, relax Satan. Don't get all worked up. You're gonna give yourself an ulcer again.",
#  257: "I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#  258: 'Touch of the flu.',
#  259: "I'm at a loss, then.  What should we talk about? Your year of absence?",
#  524548: "A deal? You wanna make a deal with the devil. Well sure, deals are mounds o' fun.",
#  261: "Why don't we discuss your driving need to be a hemorrhoid?",
#  262: "What's to discuss?",
#  263: "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  264: "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good...",
#  524553: "Well of COURSE he wants out of hell! The whole POINT of hell is that you don't WANT to be here!",
#  524554: "Okay, kid, I have a deal for you! If you want out of hell, all you have to do is collect 10 proofs of purchases from 'Snacky Smores.'  They're rich, chocolatey and really hit the spot. Bring me ten proofs of purchases and we'll grant you ANY WISH YOU WANT.",
#  524555: 'Mrph?',
#  524556: "I wouldn't bullshit you kid! Snacky Smores are now available in stores everywhere! No biggie!",
#  271: "C'esc ma tete. This is my head",
#  272: "Right.  See?  You're ready for the quiz.",
#  273: "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  274: "That's because it's such a nice one.",
#  275: 'Forget French.',
#  276: 'How is our little Find the Wench A Date plan progressing?',
#  277: "Well, there's someone I think might be --",
#  280: 'There.',
#  281: 'Where?',
#  285: 'Yeah',
#  286: 'What do you think?',
#  287: 'Two legs, nice rack...',
#  288: 'Yeah, whatever.  I want you to go out with her.',
#  289: "Sure, Sparky.  I'll get right on it.",
#  290: 'You just said',
#  291: 'You need money to take a girl out',
#  292: "But you'd go out with her if you had the cake?",
#  524581: "Alright, now I want you to say 'horsefucker.'",
#  294: 'You got it, Verona.  I pick up the tab, you do the honors.',
#  295: "You're gonna pay me to take out some girl?",
#  296: "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  297: 'How much?',
#  298: "I can't take a girl like that out on twenty bucks.",
#  299: 'Fine, thirty.',
#  300: "Take it or leave it.  This isn't a negotiation.",
#  301: "Fifty, and you've got your man.",
#  524590: 'Hi Stan.',
#  524591: 'Wow, dude. Wendy could really give a rats ass about you.',
#  304: "I mean Wo-man.  How ya doin'?",
#  305: 'Sweating like a pig, actually.  And yourself?',
#  306: "There's a way to get a guy's attention.",
#  307: 'My mission in life.',
#  628501: 'Yes.',
#  309: 'Pick you up Friday, then',
#  310: 'Oh, right.  Friday.',
#  311: "The night I take you to places you've never been before.  And back.",
#  312: 'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  313: 'I know a lot more than that',
#  524602: 'What?',
#  524603: "You know, me and Stan were just talking about what a fat fucking hunk o' fat fuck you are.",
#  524604: "Oh yeah?!  Well you're a monkey-shit-",
#  558669: 'Oh, hi.',
#  319: "I have the potential to smack the crap out of you if you don't get out of my way.",
#  320: 'Can you at least start wearing a bra?',
#  322: "You hate me don't you?",
#  323: "I don't really think you warrant that strong an emotion.",
#  324: "Then say you'll spend Dollar Night at the track with me.",
#  325: 'And why would I do that?',
#  326: 'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  327: 'You -- covered in my vomit.',
#  328: 'Seven-thirty?',
#  330: 'Are you following me?',
#  331: "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  332: 'Hi',
#  333: "You're not a big talker, are you?",
#  334: "Depends on the topic. My fenders don't really whip me into a verbal frenzy.",
#  335: 'Hey -- do you mind?',
#  336: 'Not at all',
#  524625: 'Hello there, children!!',
#  338: 'My insurance does not cover PMS',
#  339: 'Then tell them I had a seizure.',
#  340: 'Is this about Sarah Lawrence? You punishing me?',
#  341: 'I thought you were punishing me.',
#  342: "Why can't we agree on this?",
#  343: "Because you're making decisions for me.",
#  344: "As a parent, that's my right",
#  345: "So what I want doesn't matter?",
#  346: "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  347: 'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --',
#  524636: "What's the secret to making a woman happy?",
#  349: 'When I shell out fifty, I expect results.',
#  350: "I'm on it",
#  351: "Watching the bitch trash my car doesn't count as a date.",
#  352: 'I got her under control. She just acts crazed in public to keep up the image.',
#  611728: "I'll sleep around a little.",
#  354: 'I just upped my price',
#  355: 'What?',
#  356: 'A hundred bucks a date.',
#  357: 'Forget it.',
#  358: 'Forget her sister, then.',
#  87441: 'Because he knows how to get to our man.',
#  363: 'You got something on your mind?',
#  364: "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  365: 'You have my word.  As a gentleman',
#  366: "You're sweet.",
#  367: 'How do you get your hair to look like that?',
#  368: "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  524657: "Chef, what does it mean that we're at war?",
#  524658: "It's... It's not good children.",
#  371: 'Say it',
#  372: 'What?',
#  373: "Whatever the hell it is you're standin' there waitin' to say.",
#  375: 'What plan?',
#  376: 'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  377: 'What is it with this chick?  She have three tits?',
#  378: "I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's.",
#  379: "Dorsey can plow whoever he wants. I'm just in this for the cash.",
#  380: "That's where we can help you.  With Kat.",
#  381: 'So Dorsey can get the girl?',
#  382: "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl.",
#  383: 'You two are gonna help me tame the wild beast?',
#  384: "We're your guys.",
#  385: 'And he means that strictly in a non- prison-movie type of way.',
#  386: "Yeah -- we'll see.",
#  388: 'This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  389: "In that case, we'll need to make it a school-wide blow out.",
#  390: 'Will Bogey get bent?',
#  391: "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  394: "It's more",
#  395: 'Expensive?',
#  396: "Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  397: 'Hopefully.',
#  401: 'Sure have.',
#  402: "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  403: "I'm workin' on it. But she doesn't seem to be goin' for him.",
#  404: "She's not a...",
#  405: "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  406: "So that's the kind of guy she likes? Pretty ones?",
#  407: "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  524696: 'I know.',
#  524697: 'So what do you say we shut off that light and get close, huh?',
#  411: "What've you got for me?",
#  412: "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  524701: "Isn't that in Arizona or something?",
#  414: 'What?!',
#  415: 'Good enough.',
#  416: 'Number one.  She hates smokers',
#  417: "It's a lung cancer issue",
#  418: 'Her favorite uncle',
#  419: 'Dead at forty-one.',
#  420: 'Are you telling me I\'m a -  "non-smoker"?',
#  421: 'Just for now.',
#  524710: "And she's getting worse...",
#  663421: '',
#  424: "He's pretty!",
#  425: "Okay!  I wasn't sure",
#  426: 'Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  427: "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  428: 'Ever been to Club Skunk?',
#  429: 'Yeah.',
#  430: 'Gigglepuss is playing there tomorrow night.',
#  431: "Don't make me do it, man",
#  432: 'Assail your ears for one night.',
#  433: "It's her favorite band.",
#  524722: "What has the world come to? This is horrible. We're locked up, burning books, hating other people-",
#  524723: '-no Cheesy Poofs.',
#  436: 'I prefer to think of it simply as an alternative to what the law allows.',
#  437: "I'm likin' you guys better",
#  524726: 'I agree! The only way to save our future is to unite and fight!  <b>Something must be done! We must take action fast! My parents have gotten so strict they forgot they were children in the past!</b>',
#  524727: "<b>And my mom has become so bu-sy that she's raising heck and ignoring me I agree that there is now a battle to be won! Something must be done!</b>",
#  524728: 'But what are we going to do against this entire army?',
#  441: "Oh my God, does this mean you're becoming normal?",
#  442: "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  443: "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  444: 'What do you think?',
#  445: "I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  524734: 'Okay...',
#  447: "You think this'll work?",
#  448: 'No fear.',
#  524737: "I'll just try the first one.",
#  524739: "Is it Cartman's mom?",
#  524740: 'Very funny!',
#  524742: 'Oh, son of a bitch!  AAGHGH!! I mean, son of a biscuit!',
#  611745: 'And it was full of water when I drove by here three days ago. Full. I mean... a river.',
#  524744: 'Ber dada!',
#  524745: "Get out of here Ike, you're too young for this stuff!",
#  458: 'Always a pleasure, Brucie.',
#  459: "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  460: 'Fan of a fan.  You see a couple of minors come in?',
#  461: 'Never',
#  462: 'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  463: "Just sent 'em through.",
#  524752: "Bingo. Okay, here we go...  Want to help Terrance and Phillip? Meet us for a meeting at Gladdy's barn tomorrow night...",
#  524753: "Tell 'em we'll have pie and punch.",
#  524754: "We're not gonna have pie and punch!",
#  524755: "More people will come if they think there'll be pie and punch!",
#  524756: 'pie and punch... This is Top Secret. The password is...',
#  524758: "You stay up here in the attic, Ike. Don't make any noises or nothing, okay?",
#  524759: 'Uhh...',
#  524760: "Goodnight, Ike, we're all going to bed.",
#  473: 'hey.  Great show, huh?',
#  474: '',
#  475: 'Excuse me?',
#  476: "That's what you want, isn't it?",
#  477: "Do you mind?  You're sort of ruining it for me.",
#  524766: 'Well find out where that signal is coming from!  Then hunt them down like dogs! Any and all Canadian influence must be stopped at all cost!',
#  87461: 'You could fake it.',
#  524768: 'And Bill?',
#  481: "You know, these guys are no Bikini Kill or The Raincoats, but they're right up there.",
#  482: 'You know who The Raincoats are?',
#  483: "Why, don't you?",
#  87462: "You're wrong to sell Ich short.",
#  524774: 'Goodnight, honey.',
#  524775: 'Mom... When is the war gonna be over?',
#  524776: "I don't know honey. Soon we hope. You want it to end quickly, huh?",
#  524777: "Oh, I don't care, I was just asking cuz all my favorite TV shows have been replaced by news and it's pissing me off.",
#  490: "What'd he say?",
#  491: 'Who cares?',
#  524780: 'Yes, hon?',
#  524781: "If you went down on a horse... You'd tell me, right?",
#  524782: 'Sure, hon. Goodnight.',
#  524784: 'Eric?! Eric, what is it?!',
#  611752: "Cuz I'm a skin?",
#  524786: "Oh you poor dear. You've been through so much...",
#  499: 'You told me that part already.',
#  500: "Hell, I've just been going over the whole thing in my head and -",
#  502: "I hear you're helpin' Verona.",
#  503: "Uh,  yeah.  We're old friend*",
#  504: 'You and Verona?',
#  505: 'What?  We took bathes together when we were kids.',
#  524794: 'What did you do today Satan?',
#  524795: "You don't care.",
#  508: "You better not fuck this up.  I'm heavily invested.",
#  509: "Hey -- it's all for the higher good right?",
#  524798: "That's because I wanted to fuck you, dumbass! Now hows aboot you get those pants down!",
#  511: "You're completely demented.",
#  512: 'See you next week!',
#  87467: "Where's the wife?",
#  517: 'Daddy, I --',
#  518: "And where're you going?",
#  519: 'If you must know, we were attempting to go to a small study group of friends.',
#  520: 'Otherwise known as an orgy?',
#  521: 'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  524810: "I have to say 'behind'! I get shocked if I say 'ass-  OW!!!",
#  523: 'Daddy, people expect me to be there!',
#  524: "If Kat's not going, you're not going.",
#  525: "You're ruining my life'  Because you won't be normal, I can't be normal.",
#  526: "What's normal?",
#  527: "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  524816: 'YOU DO?!',
#  529: "Can't you forget for just one night that you're completely wretched?",
#  530: "At least I'm not a clouted fen- sucked hedge-pig.",
#  531: "Like I'm supposed to know what that even means.",
#  532: "It's Shakespeare.  Maybe you've heard of him?",
#  533: "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  524822: "What's the password?",
#  524377: 'About what?',
#  536: "Oh, God.  It's starting.",
#  537: "It's just a party. Daddy.",
#  538: 'Wear the belly before you go.',
#  539: 'Daddy, no!',
#  540: 'Just for a minute',
#  524378: 'About Cheesy Poofs, dumbass! This whole thing has gone too far!',
#  542: 'You are so completely unbalanced.',
#  543: 'Can we go now?',
#  544: "Promise me you won't talk to any boys unless your sister is present.",
#  545: 'Why?',
#  546: "Because she'll scare them away.",
#  524835: 'Yeah, so what do we say?',
#  524836: 'I thought you had something planned.',
#  524837: 'Me?!',
#  524841: 'May I?',
#  554: 'Where ya goin?',
#  555: 'Away.',
#  556: 'Your sister here?',
#  557: 'Leave my sister alone.',
#  558: 'And why would I do that?',
#  524848: "WE'RE going! WE started La Resistance to save Terrance and Phillip! We're going!",
#  524849: 'This will be very dangerous... Are you quite sure?',
#  524850: 'Fuck that!  AGAGH!!',
#  611763: "I can't, Hoss. I don't talk to FBI's.",
#  564: "What's this?",
#  565: '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  566: 'I say, do what you wanna do.',
#  567: "Funny, you're the only one",
#  611764: "You think you was sent here cuz you're a good cop?",
#  571: 'Where did he go?  He was just here.',
#  572: 'Who?',
#  573: 'Joey.',
#  568124: 'And talking is talking! Well, I think we better get on.',
#  575: 'Hi.',
#  576: 'Looks like things worked out tonight, huh?',
#  577: 'You know Chastity?',
#  578: 'I believe we share an art instructor',
#  579: 'Great',
#  580: 'Would you mind getting me a drink, Cameron?',
#  583: 'Extremely unfortunate maneuver.',
#  584: "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  585: "Buttholus extremus.  But hey, you're making progress.",
#  586: "No, I ' m not.",
#  589: 'So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  590: 'Queen Harry?',
#  591: "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  592: 'Neat...',
#  593: "My agent says I've got a good shot at being the Prada guy next year.",
#  595: "He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  596: 'Is he oily or dry?',
#  597: "Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  598: "Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  599: "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  600: "All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  601: 'Bianca, I need to talk to you -- I need to tell you --',
#  602: "I really don't think I need any social advice from you right now.",
#  605: "It's about time.",
#  606: "A deal's a deal.",
#  607: "How'd you do it?",
#  608: 'Do what?',
#  609: 'Get her to act like a human',
#  610: 'Okay?',
#  611: "I'm fine. I'm",
#  612: "You're not okay.",
#  613: 'I just need to lie down for awhile',
#  614: "Uh, uh. You lie down and you'll go to sleep",
#  615: 'I know, just let me sleep',
#  616: 'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...',
#  619: "Cameron, I'm a little busy",
#  620: "It's off. The whole thing.",
#  621: "What 're you talking about?",
#  622: "She's partial to Joey, not me",
#  623: 'Cameron -- do you like the girl?',
#  624: 'Sure',
#  625: 'Then, go get her',
#  626: 'This is so patronizing.',
#  627: "Leave it to you to use big words when you're shitfaced.",
#  628: "Why 're you doing this?",
#  629: 'I told you',
#  630: "You don't care if I die",
#  631: 'Sure, I do',
#  632: 'Why?',
#  633: "Because then I'd have to start taking out girls who like me.",
#  634: 'Like you could find one',
#  635: "See that?  Who needs affection when I've got blind hatred?",
#  636: 'Just let me sit down.',
#  524925: "Him? I don't know... He can be nice... sometimes.",
#  524926: 'Mph rmph rm rmph rm.',
#  639: "Why'd you let him get to you?",
#  640: 'Who?',
#  641: 'Dorsey.',
#  642: 'I hate him.',
#  643: "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  644: 'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  645: 'I thought you were above all that',
#  646: 'You know what they say',
#  524396: "Eric!  Don't talk to Ms. Brovlofski that way!",
#  650: 'Kat! Wake up!',
#  651: 'What?',
#  524940: 'Do you see them?  Do you see Terrance and Phillip?',
#  524941: 'No. Zey must have zem inside. We will have to dig.',
#  524942: "That's gonna take a long time!",
#  655: "I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  656: "You're welcome.",
#  659: 'I have to be home in twenty minutes.',
#  660: "I don't have to be home 'til two.",
#  662: 'Have fun tonight?',
#  663: 'Tons',
#  524952: "Dude, this is seriously lame. I didn't know we were gonna get all dirty and stuff.",
#  524953: 'Sheet!',
#  524954: 'What is it?',
#  524955: 'Bedrock!  I cannot dig any further in zis direction!',
#  668: "And I'm in control of it.",
#  669: "But it's Gigglepuss - I know you like them.  I saw you there.",
#  670: 'When you were gone last year -- where were you?',
#  671: 'Busy',
#  672: 'Were you in jail?',
#  673: 'Maybe.',
#  674: "No, you weren't",
#  675: "Then why'd you ask?",
#  676: "Why'd you lie?",
#  677: 'I should do this.',
#  678: 'Do what?',
#  679: 'This.',
#  680: 'Start a band?',
#  681: "My father wouldn't approve of that that",
#  682: "You don't strike me as the type that would ask permission.",
#  683: 'Oh, so now you think you know me?',
#  684: "I'm gettin' there",
#  524973: 'Now listen carefully. Stan and Kyle, you stand watch here and await my return. If any guards come by, make a sound like a dying giraffe.',
#  686: "So what ' s up with your dad?  He a pain in the ass?",
#  687: "He just wants me to be someone I'm not.",
#  688: 'Who?',
#  689: 'BIANCA',
#  690: "No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  524979: 'You MUST shut off the power, this is VERY IMPORTANT do you understa-',
#  524980: "I HEARD YOU THE FIRST TIME! I'M NOT LOU FERIGNO FOR PETE'S SAKE!",
#  693: 'I looked for you back at the party, but you always seemed to be "occupied".',
#  694: 'I was?',
#  695: "You never wanted to go out with 'me, did you?",
#  696: 'Well, no...',
#  697: "Then that's all you had to say.",
#  698: 'But',
#  699: 'You always been this selfish?',
#  543991: "Don't talk like that. Get yourself home as fast as you can.",
#  611786: "Remember that upside down flag back at Jimmy's house? Somebody took it down.",
#  611787: 'Good.',
#  716: 'You went to the party?  I thought we were officially opposed to suburban social activity.',
#  717: "I didn't have a choice.",
#  718: "You didn't have a choice?  Where's Kat and what have you done with her?",
#  719: 'I did Bianca a favor and it backfired.',
#  720: "You didn't",
#  721: 'I got drunk.  I puked.  I got rejected. It was big fun.',
#  723: 'So you got cozy with she who stings?',
#  724: "No - I've got a sweet-payin' job that I'm about to lose.",
#  725: "What'd you do to her?",
#  726: "I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  728: 'Hey there.  Tired of breathing?',
#  729: 'Hi.',
#  730: 'Cool pictures.  You a fan?',
#  731: 'Yeah.  I guess.',
#  732: 'You think?',
#  733: 'Oh yeah.',
#  525022: 'AGAGAH!!',
#  735: 'Macbeth, right?',
#  736: 'Right.',
#  737: 'Kat a fan, too?',
#  738: 'Yeah...',
#  740: "She hates you with the fire of a thousand suns .  That's a direct quote",
#  741: "She just needs time to cool off I'll give it a day.",
#  743: "You makin' any headway?",
#  744: 'She kissed me.',
#  745: 'Where?',
#  525034: 'Oh, brother.',
#  747: "I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  748: "Enough with the Barbie n' Ken shit. I know.",
#  525037: 'Whoops.',
#  750: 'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  751: "Well, I guess we're not, since we don't have dates .",
#  752: 'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  753: "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  754: "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  755: 'Oh, good.  Something new and different for us.',
#  756: 'Hey, sweet cheeks.',
#  757: 'Hi, Joey.',
#  758: "You're concentrating awfully hard considering it's gym class.",
#  759: 'Listen, I want to talk to you about the prom.',
#  760: "You know the deal.  I can ' t go if Kat doesn't go --",
#  525049: 'FREEZE!!',
#  524415: "You've got a stupid accent too.",
#  764: 'Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  765: 'What are you doing here?',
#  766: 'I heard there was a poetry reading.',
#  767: "You 're so --",
#  768: 'Pleasant?',
#  769: 'Wholesome.',
#  770: 'Unwelcome.',
#  771: 'Unwelcome?  I guess someone still has her panties in a twist.',
#  772: "Don't for one minute think that you had any effect whatsoever on my panties.",
#  773: 'So what did I have an effect on ?',
#  774: 'Other than my upchuck reflex? Nothing.',
#  775: "You were right. She's still pissed.",
#  776: 'Sweet love, renew thy force!',
#  777: "Man -- don't say shit like that to  me. People can hear you.",
#  778: 'You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  779: "Best case scenario, you're back on the payroll for awhile.",
#  780: "What's the worst?",
#  781: 'You get the girl.',
#  611800: 'You burned an American flag today. And left it for me...',
#  525075: 'Kyle?!',
#  525076: 'Eric?',
#  611801: '-- You desecrated it, it had to be burned.',
#  576143: "...I gotta hand it to him, he tossed a lot of sand in their eyes. He talked about how I'd lost my place in the universe...",
#  87514: 'With these?',
#  798: 'He left!  I sprung the dickhead and he cruised on me.',
#  799: 'Look up, sunshine',
#  800: "I guess I never told you I'm afraid of heights.",
#  801: "C'mon.  It's not that bad",
#  802: "Try lookin' at it from this angle",
#  803: 'Put your right foot there --',
#  804: "Forget it.  I'm stayin'.",
#  805: 'You want me to climb up and show you how to get down?',
#  806: 'Maybe.',
#  525095: 'KYLE BROVLOFSKI, YOU WATCH YOUR LANGUAGE!!',
#  808: 'The Partridge Family?',
#  809: 'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  810: 'Good call.',
#  811: "So how'd you get Chapin to look the other way?",
#  812: 'I dazzled him with my wit',
#  813: 'A soft side? Who knew?',
#  814: "Yeah, well, don't let it get out",
#  815: "So what's your excuse?",
#  816: 'Acting the way we do.',
#  817: 'Yes',
#  818: "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  819: "So if you disappoint them from the start, you're covered?",
#  820: 'Something like that',
#  821: 'Then you screwed up',
#  822: 'How?',
#  823: 'You never disappointed me.',
#  824: 'You up for it?',
#  825: 'For. . . ?',
#  576144: "...a puny player on the great world's stage...",
#  828: 'State trooper?',
#  829: 'Fallacy.',
#  830: 'The duck?',
#  831: 'Hearsay.',
#  832: "I know the porn career's a lie.",
#  525121: 'Canada is saving us!!',
#  834: 'Tell me something true.',
#  835: 'I hate peas.',
#  836: 'No -- something real.  Something no one else knows.',
#  837: "You're sweet.  And sexy.  And completely hot for me.",
#  838: 'What?',
#  839: 'No one else knows',
#  840: "You're amazingly self-assured. Has anyone ever told you that?",
#  841: 'Go to the prom with me',
#  842: 'Is that a request or a command?',
#  843: 'You know what I mean',
#  844: 'No.',
#  845: 'No what?',
#  846: "No, I won't go with you",
#  847: 'Why not?',
#  848: "Because I don't want to. It's a stupid tradition.",
#  87523: "Nick, you can't do this.",
#  852: 'Create a little drama?  Start a new rumor?  What?',
#  853: 'So I have to have a motive to be with you?',
#  854: 'You tell me.',
#  855: 'You need therapy.  Has anyone ever told you that?',
#  856: 'Answer the question, Patrick',
#  857: "Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  524431: 'This is NOT a place for fun and games! This is rehabilitation! Now GET TO IT!! We at MAC have a trial to go to!',
#  860: 'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  861: 'No...',
#  862: 'do you listen to this crap?',
#  863: 'What crap?',
#  864: "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  865: 'Thank God!  If I had to hear one more story about your coiffure...',
#  866: "I figured you'd get to the good stuff eventually.",
#  867: 'What good stuff?',
#  868: 'The "real you".',
#  869: 'Like my fear of wearing pastels?',
#  870: 'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  871: 'No',
#  872: "Okay -- you're gonna need to learn how to lie.",
#  525161: 'AGH!',
#  525162: 'Terrance! NO!',
#  876: 'Would you rather be ravished by a pirate or a British rear admiral?',
#  877: 'Pirate -- no question.',
#  878: "Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  879: 'The prom?  Kat has a date?',
#  880: 'No, but',
#  881: "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  882: 'He\'s not a "hot rod".  Whatever that is.',
#  883: "You're not going unless your sister goes.  End of story.",
#  884: "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  886: "They'll dance, they'll kiss, they'll come home.  Let her go.",
#  887: "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  889: "Listen, I know you hate having to sit home because I'm not Susie High School.",
#  890: 'Like you care.',
#  891: "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  892: "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  893: 'Joey never told you we went out, did he?',
#  894: 'What?',
#  895: 'In 9th.  For a month',
#  896: 'Why?',
#  897: 'He was, like, a total babe',
#  898: 'But you hate Joey',
#  899: 'Now I do.  Back then, was a different story.',
#  900: 'As in...',
#  901: 'He said everyone was doing it.  So I did it.',
#  902: 'You did what?',
#  903: "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  904: 'But',
#  905: 'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  906: "Why didn't you tell me?",
#  907: 'I wanted to let you make up your own mind about him.',
#  908: "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  909: "That's not",
#  910: "I'm not stupid enough to repeat your mistakes.",
#  911: 'I guess I thought I was protecting you.',
#  912: "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  913: "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  914: "I guess I'll never know, will I?",
#  576147: "...He told them to look at me--look at me close. That the closer they looked the less sense it would all make, that I wasn't the kind of guy to kill a guy, that I was the barber, for Christ's sake...",
#  917: "What do you wanna watch?  We've got crap, crap, crap or crap",
#  918: 'Dr. Ruth?',
#  558689: 'Are you okay?',
#  525209: "No, Saddam. You made a deal. You can't just renege on a deal. That's lying.",
#  922: "I'm missing something.",
#  923: "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  924: 'Wow',
#  925: "Let's go.",
#  926: 'Have a great time, honey!',
#  927: 'But -- who -- what --?',
#  525216: "It's that v-chip thing that's inside you, Eric!  The polarity must have been reversed by the electric chair!",
#  929: 'What just happened?',
#  930: 'Your daughters went to the prom.',
#  931: 'Did I have anything to say about it?',
#  932: 'Absolutely not.',
#  933: "That ' s what I thought",
#  611825: "-- never mind Eagle Bear. We've got Jimmy nailed. Let's go!",
#  936: "How'd you get a tux at the last minute?",
#  937: "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  938: "It's just something I had.  You know",
#  939: 'Oh huh',
#  940: "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  524445: 'The young boy that died lit himself on fire. It was unfortunate, but how can they blame US?',
#  525232: "Help you? You've destroyed my life and now you want me to help you?!  You're always making me feel like a piece of shit.",
#  525233: 'Come on guy, you know I only rib you because I love you so much!',
#  946: 'Have you seen him?',
#  947: 'Who?',
#  948: 'William - he asked me to meet him here.',
#  949: "Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  525238: "Listen guy, you're embarassing me in front of my friends!  You know how I get mad when I get embarassed.",
#  952: "You think you ' re the only sophomore at the prom?",
#  953: 'I did.',
#  957: "My grandmother's .",
#  958: 'What?',
#  959: "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  960: "That ' s completely adorable!",
#  961: 'It gets worse -- you still have your freshman yearbook?',
#  525255: 'WHAT?',
#  525256: 'Are you sure, Kenny?',
#  628523: 'Well, I have to admit, walkin\' through the door and seein\' these "Soldier of Fortune" poster boys made me a bit nervous. But, Lee, I\'m fairly confident that you came here to do business, not to be a wise-guy. So, if you want, I\'ll put the gun on the table.',
#  973: 'Wait I...',
#  974: 'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  975: "It wasn't like that.",
#  976: 'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  977: "I didn't care about the money.",
#  525269: 'Thank you, Kenny.',
#  982: 'You looked beautiful last night, you know.',
#  983: 'So did you',
#  984: 'She okay?',
#  985: 'I hope so.',
#  986: 'Was that your sister?',
#  987: 'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  988: 'Funny.',
#  989: "I don't understand the allure of dehydrated food.  Is this something I should be hip to?",
#  990: 'No, Daddy.',
#  991: 'So tell me about this dance. Was it fun?',
#  992: 'Parts of it.',
#  993: 'Which parts?',
#  994: 'The part where Bianca beat the hell out of some guy.',
#  995: 'Bianca did what?',
#  996: "What's the matter?  Upset that I rubbed off on her?",
#  997: 'No -- impressed.',
#  998: "You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game.",
#  999: 'When I go?',
#  1000: "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check.",
#  525289: 'No, dude. Fuck him. Fuck him in the ear.',
#  525290: 'Cool!',
#  525291: "<b>Thank my lucky stars Here before me now Is everything I'd ever hoped for-</b>",
#  525292: "<b>Knew it in a word Saw it in a glance The only thing I think I'd die for</b>",
#  1007: 'Let go!',
#  1008: 'You set me up.',
#  1009: 'I just wanted --',
#  1010: 'What? To completely damage me?  To send me to therapy forever? What?',
#  1011: 'No! I just wanted',
#  525303: "I'm fine.",
#  525304: 'Congratulations on your...recent award.',
#  1017: 'Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?',
#  1018: 'Just smack her now.',
#  525307: 'No, just enjoying the view.',
#  525308: "Well, there's no better to way to see the world, than with us.",
#  1021: 'Is that woman a complete fruit-loop or is it just me?',
#  1022: "It's just you.",
#  628525: 'Oh, Mr. Donowitz -',
#  1031: 'A Fender Strat. You bought this?',
#  1032: 'I thought you could use it. When you start your band.',
#  1033: 'Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  1034: 'Is that right?',
#  1035: 'Yeah, but then I fucked up. I fell for her.',
#  525324: "Homesick?  It's only been two days!",
#  525325: 'We should have gone to Nassau. At least we could go swimming, lie on the beach.',
#  525326: 'Ah hell we can always do that. Listen believe me, once we get to the moon, your tone is going to change.',
#  525327: 'How is it going to be different from this?  Go see some boring footprint under glass?',
#  1040: 'Why is my veggie burger the only burnt object on this grill?',
#  1041: 'Because I like to torture you.',
#  1042: 'Oh, Bianca?  Can you get me my freshman yearbook?',
#  1043: "Don ' t you even dare. . .",
#  1044: 'They do to!',
#  1045: 'They do not!',
#  525336: "Why should she, it's her fault. All guests are told not to eat in zero gravity, but she just wanted to have fun I guess, didn't realize what a grain of salt can do to sophisticated machinery.",
#  525337: "Well, I guess she figures she's paying for it.",
#  525338: "Ain't it the truth. Must be good to be rich.",
#  1051: 'Patrick -- is that- a.',
#  1052: 'Perm?',
#  470668: "Don't let 'im get you tight.",
#  525342: "Sounds like you've been talking to Mac too much.",
#  628526: "Lee, Clarence . Please don't insult me. Call me Lee.",
#  525349: 'Evening.',
#  525350: "It can't be.",
#  525351: 'Excuse me?',
#  525352: "You're Warren Wayne.",
#  525353: 'Uh, yes I am.  And you are?',
#  525354: 'Anna Koros. She sensually extends her hand, Warren shakes it -',
#  611847: 'Why?',
#  525356: "My grandfather.  My God, I can't tell you what a fan I am of yours! You were magnificent in Deadly Gamble.",
#  525357: 'Oh, thank you.',
#  525358: 'Magnificent, magnificent.',
#  525359: 'Well I appreciate that.',
#  525360: 'So, what brings you out here?  Pleasure cruise?',
#  611848: 'Cuz I want New York.',
#  525362: 'Of course, of course...',
#  525363: 'So...',
#  525364: "Well I guess we're neighbors for this trip.",
#  525365: 'Well, so we are.  Sure is beautiful, huh?',
#  525366: 'It certainly is.',
#  525367: 'Well, it was nice meeting you. Enjoy the rest of the trip.',
#  525368: "I'm sure I will.",
#  558662: 'Are you kidding? I knew it all the time. Did you see how they fell into our trap? Beautiful . . .',
#  525376: 'No, I just ran it!  Why are you running it again?',
#  525377: "Well it's a good thing that I did.",
#  525378: "It's telling me fail mode confirmed.  Did you see this?",
#  525379: 'There must be some mistake. You sure you hit the right commands?',
#  525380: "Yes I'm sure I hit the right commands.",
#  525381: "Why don't you reset and run it again.  The pods check out ok.",
#  525382: "You're certain of that?",
#  525383: "Trust me.  Even checked 'em with my own eyes.",
#  525384: "All right, I'll give it a shot.",
#  525387: "Oh right, right you're on that research grant.",
#  525388: "That's right.",
#  525389: 'Ryan Taylor, first mate.  Welcome aboard.  First time in space?',
#  525390: "Yes.  Theoretical discoveries aside, there's nothing like the real thing. How about you?",
#  525391: 'This is my second commercial flight.  I used to run satellite freighters but that got old fast.',
#  525392: 'So you were looking for a new challenge.',
#  525393: "Well, plus the money ain't that bad. DAWN So, tell me, do you think everyone gets their million dollars' worth on this trip of a lifetime?",
#  525394: 'Well, let me put it this way.  Most of the cost is due to safety reasons. Most people are not familiar with space travel, so we have to take extra precautions in the event they do something careless.',
#  525395: 'Like open an airlock by mistake?',
#  525396: "Well I don't think there's a chance of that happening.  It's usually the moon walks.  Sometimes you feel like a kindergarten teacher.",
#  611854: 'Must be a bitch getting around in that wheelchair. How long you been in it?',
#  525398: "I'm sure you'll be all right.",
#  525399: "Actually I've logged about 200 hours of simulated space walking at the institute, mostly related to starship construction.",
#  525400: 'Really?',
#  525401: "Still, I hope I behave on the moon.  I'll stick close to you.",
#  611855: "Since I got a iron pipe put across my knees, man. Fight with three wasi'cus, ya know.",
#  525404: "Yeah, I guess money don't buy class.",
#  525405: 'No.  But it buys a lot of other things.',
#  525406: 'Like that piece of ass he was with.',
#  525407: "Well...I don't mind.  I can put up with it.  I'm taking six months off after this, and I won't have to deal with people snapping their fingers at me.",
#  525408: "Not me.  I'm in for the long haul. In nine months I'll have enough to take a few years off.",
#  525409: 'Well, more power to you.  Me, I start to bug out after too much time out here.',
#  525410: "I don't have a problem with it. Besides, you get to meet a lot of interesting people.",
#  87569: "Ugly... A couple of thousand years they've been bound by these little rules.  Looking in.  Always afraid. Ugly little lives...",
#  525418: "Oh no...I think there's carrots in here...",
#  525419: "Send it back if you don't want it.",
#  87570: 'Save it, I already took the tour.',
#  524477: 'Oh, you are such a maroon!',
#  87571: "You are a lucky man.  Where you come from a man can stand out.  It's expected.  Here a man is made to look a fool for standing out.",
#  524478: 'You would know, dummy.',
#  611860: "No. Can't say that I have, Richard. Richard do you know why I'm here?",
#  525434: 'No, I think hygiene is important. It helps you get into the part.',
#  525435: 'Very professional of you.',
#  611861: 'Washington sent ya. I know that.',
#  524480: 'WHAT THE HELL WAS THAT?!',
#  525444: "Well, everything's running smoother than a baby's ass.",
#  611862: 'Yes, Washington sent me, Richard. They sent me here because this whole thing has been fucked. Do you know what I mean when I say this whole thing has been fucked, Richard?',
#  525446: 'So, are you on for the next one?',
#  524481: 'Dude, they cut out 92 minutes!',
#  525448: "Why, didn't they say?",
#  525449: "Well that hotel begins construction in January, there's going to be a lot of shuttle work.",
#  525450: 'You want to go back to shuttle work?',
#  525451: "It's steady, good benefits.",
#  525452: 'You gotta think of your old age.',
#  524482: "So you see, the point and the theme of the film is kept intact. And of course, the MPAA didn't cut out any of the graphic violence. What did you think?",
#  525454: 'Thank you.',
#  525455: "Man, I'm hungry.  I'm going to call the steward, you want anything?.",
#  525456: "Nah, I already ate.  Why don't you just go down there?",
#  525457: 'What, and leave you here all by your lonesome?',
#  525458: 'Uh...',
#  524483: "Oh man, I'm gonna need a cherry pie to get the taste of ass out of my mouth from that piece of shit movie.",
#  525460: "Well, maybe I will.  You sure you don't want anything?",
#  525461: "No.  I'm all set.  Thanks.",
#  525462: "Well, maybe I'll surprise you.",
#  611865: "Not for long, Richard. You got early parole under the stipulation that you would help us in a situation, and you didn't deliver.",
#  525464: 'Officer Taylor, how are you this evening?',
#  524484: "Eric, you're not watching your mouth!",
#  572629: 'What are you doing?',
#  611866: "What the fuck you talkin' about?",
#  524485: "You get me Cheesy Poofs with the delightful cheddar crunch, and I'll watch my fucking mouth!",
#  611867: 'Get up out of the chair, Richard.',
#  524486: 'Eric!!!!  You need to be rehabilitated. Help me to help you!',
#  525478: "It's a little late for you to be up.",
#  525479: 'Look answer my question!',
#  524487: 'Help yourself prickfuck!',
#  525484: 'All too well, captain.',
#  525485: 'Well shut it off at once!',
#  524488: 'I am not a prickfuck, mkay? You little asshole!',
#  525494: 'Bridge!  Can anyone hear me?!',
#  525495: 'Yeah yeah yeah, give me a minute here.',
#  525497: 'If anyone can hear me please respond!',
#  525498: "That's very professional sounding of you, Taylor.",
#  611871: 'Get up!',
#  525500: 'Barnes, can you hear me, are you all right?',
#  524490: "How is the children's progress?",
#  525502: 'What is the condition of the bridge?',
#  525503: 'The bridge is fine, Taylor, how are things down there?',
#  525504: "Transmit the code 3 emergency and take us offline.  Override the airlock sensors and hurry!  We're running out of time, we have to get to the pods!",
#  611872: "They said I'd never see FBI again, and I'm livin' with you fuckers. I don't feed ya information on the Warriors, it's back to the pen. I don't do this, back to the pen. Your word against my word. Against a con Indian's word. I really got a chance, man, right?",
#  525506: 'What are you talking about! Can you transmit the code 3 -',
#  524491: 'Very encouraging. Most of the children have been weened from their naughty mouths.',
#  525511: 'Now do you want the good news first or the bad news?',
#  525512: 'You better start making sense!',
#  524492: 'What do you mean MOST, why not ALL?',
#  525514: "Then we've got to get to the lifepods!",
#  525515: "I'd advise you to shut up and let me finish Taylor.  You needn't worry about the lifepods because they're all gone, jettisoned. Save for one.",
#  524493: "Well, some of the children just don't respond to 12 step programs.",
#  453951: 'What?',
#  524494: "Then we'll have to resort to plan B and call the v-chip organization.",
#  611876: "No way. No fuckin' way.",
#  524495: "Mrs. Brovlofski, the V-chip hasn't been fully tested yet, it could be dangerous.",
#  525532: "Who said I'll re-enter in the pod? I got friends out in space, Ryan, friends willing to get me back unnoticed.  Thank God for deregulation huh?",
#  87589: "For God's sake, Ohashi, I need your help.  Let me out of here!",
#  524496: "I don't care if it's dangerous! Desperate times call for desperate measures, Mr. Mackey. Perhaps I need to remind you of your situation.",
#  525538: "I don't know.",
#  87590: 'You had my help, detective.',
#  525542: "Well maybe there's a way out of here.",
#  525543: "Fat chance of that.  Even if we had C4 and a laser torch these doors wouldn't budge.  That son of a bitch...that stupid son of a bitch.",
#  525544: "Given a malfunction, how would a rescue team get you out if the doors won't open?",
#  525545: 'Probably come through the wall I suppose.',
#  525546: 'Well maybe we can do something like that.',
#  ...}

# %%
# idと会話をセットにする
sorted_chats = sorted(chats.items(), key = lambda x: x[0])
sorted_chats
# Out:
# [(49, 'Did you change your hair?'),
#  (50, 'No.'),
#  (51, 'You might wanna think about it'),
#  (59, 'I missed you.'),
#  (60, 'It says here you exposed yourself to a group of freshmen girls.'),
#  (61, 'It was a bratwurst.  I was eating lunch.'),
#  (62, 'With the teeth of your zipper?'),
#  (63, 'You the new guy?'),
#  (64, 'So they tell me...'),
#  (65, "C'mon.  I'm supposed to give you the tour."),
#  (66, 'So -- which Dakota you from?'),
#  (67, "North, actually.  How'd you   ?"),
#  (68, 'I was kidding. People actually live there?'),
#  (69, "Yeah.  A couple.  We're outnumbered by the cows, though."),
#  (70, 'How many people were in your old school?'),
#  (71, 'Thirty-two.'),
#  (72, 'Get out!'),
#  (73, 'How many people go here?'),
#  (74, 'Couple thousand. Most of them evil'),
#  (77, "That I'm used to."),
#  (78,
#   'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.'),
#  (87, 'That girl -- I --'),
#  (88, 'You burn, you pine, you perish?'),
#  (89, 'Who is she?'),
#  (90, "Bianca Stratford.  Sophomore. Don't even think about it"),
#  (91, 'Why not?'),
#  (92,
#   "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility."),
#  (103,
#   "Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again."),
#  (104, 'Expressing my opinion is not a terrorist action.'),
#  (105,
#   "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested."),
#  (106,
#   'I still maintain that he kicked himself in the balls.  I was merely a spectator.'),
#  (107, 'The point is Kat -- people perceive you as somewhat ...'),
#  (108, 'Tempestuous?'),
#  (109, 'No ... I believe "heinous bitch" is the term used most often.'),
#  (123, "Who's that?"),
#  (124, 'Patrick Verona   Random skid.'),
#  (125,
#   "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies."),
#  (126,
#   "I'm sure he's completely incapable of doing anything that interesting."),
#  (127, 'He always look so'),
#  (128, 'Block E?'),
#  (129, 'Mandella, eat.  Starving yourself is a very slow way to die.'),
#  (130, 'Just a little.'),
#  (131, "What's this?"),
#  (132, 'An attempted slit.'),
#  (133,
#   "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy."),
#  (134, "But imagine the things he'd say during sex."),
#  (139, 'Why do girls like that always like guys like that?'),
#  (140,
#   "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted."),
#  (141, 'He always have that shit-eating grin?'),
#  (142,
#   "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out."),
#  (143, 'You know French?'),
#  (144, "Sure do ... my Mom's from Canada"),
#  (145, 'Guess who just signed up for a tutor?'),
#  (146, "You mean I'd get a chance to talk to her?"),
#  (147, 'You could consecrate with her, my friend.'),
#  (148, "The vintage look is over, Kat. Haven't you been reading your Sassy?"),
#  (149,
#   'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.'),
#  (150, "They're running the rest of me next month."),
#  (151, 'The people at this school are so incredibly foul.'),
#  (152, "You could always go with me.  I'm sure William has some friends."),
#  (157, 'Yeah, just a minor encounter with the shrew.'),
#  (158, "That's her?  Bianca's sister?"),
#  (159, 'The mewling, rampalian wretch herself.'),
#  (161, 'In the microwave.'),
#  (162, 'Make anyone cry today?'),
#  (164, "Where've you been?"),
#  (165, 'Nowhere... Hi, Daddy.'),
#  (170, "What's a synonym for throbbing?"),
#  (171, 'Sarah Lawrence is on the other side of the country.'),
#  (172, 'I know.'),
#  (173, 'I thought we decided you were going to school here.  At U of 0.'),
#  (174, 'You decided.'),
#  (179,
#   "Now don't get upset. Daddy, but there's this boy... and I think he might ask..."),
#  (180,
#   "No! You're not dating until your sister starts dating.  End of discussion."),
#  (181, 'What if she never starts dating?'),
#  (182, "Then neither will you.  And I'll get to sleep at night."),
#  (183, "But it's not fair -- she's a mutant, Daddy!"),
#  (184, 'This from someone whose diary is devoted to favorite grooming tips?'),
#  (185, 'Enough!'),
#  (189, "But she doesn't want to date."),
#  (190, 'Exactly my point'),
#  (191,
#   'Jesus!  Can a man even grab a sandwich before you women start dilating?'),
#  (192, 'Tumescent!'),
#  (193, "You're not helping."),
#  (194,
#   'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.'),
#  (195,
#   "Well, I thought we'd start with pronunciation, if that's okay with you."),
#  (196, 'Not the hacking and gagging and spitting part.  Please.'),
#  (197,
#   "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?"),
#  (198, "You're asking me out.  That's so cute. What's your name again?"),
#  (199, 'Forget it.'),
#  (200, "No, no, it's my fault -- we didn't have a proper introduction ---"),
#  (201, 'Cameron.'),
#  (202,
#   "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does."),
#  (203, 'Seems like she could get a date easy enough...'),
#  (204, 'Why?'),
#  (205,
#   'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.'),
#  (206, "That's a shame."),
#  (207, 'Gosh, if only we could find Kat a boyfriend...'),
#  (208, 'Let me see what I can do.'),
#  (210,
#   'I teach her French, get to know her, dazzle her with charm and she falls in love with me.'),
#  (211,
#   "Unlikely, but even so, she still can't go out with you.  So what's the point?"),
#  (212, 'What about him?'),
#  (213, 'You wanna go out with him?'),
#  (215, "What makes you think he'll do it?"),
#  (216, 'He seems like he thrives on danger'),
#  (217,
#   "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz..."),
#  (218, 'They always let felons sit in on Honors Biology?'),
#  (219,
#   "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers."),
#  (220, "Forget his reputation.  Do you think we've got a plan or not?"),
#  (221, "Did she actually say she'd go out with you?"),
#  (222, "That's what I just said"),
#  (223,
#   "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side."),
#  (224, 'I thought you hated those people.'),
#  (225, "Hey -- I've gotta have a few clients when I get to Wall Street."),
#  (231, 'Hey.'),
#  (232, 'Are you lost?'),
#  (233, 'Nope - just came by to chat'),
#  (234, "We don't chat."),
#  (235,
#   "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested."),
#  (236, "We're not."),
#  (238,
#   "But she can't go out with you because her sister is this insane head case and no one will go out with her. right?"),
#  (239, 'Does this conversation have a purpose?'),
#  (240,
#   "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job."),
#  (244, 'You got him involved?'),
#  (245,
#   "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca."),
#  (247,
#   'So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.'),
#  (248, 'William would never have gone to a state school.'),
#  (249, "William didn't even go to high school"),
#  (250, "That's never been proven"),
#  (251, 'Neither has his heterosexuality.'),
#  (252,
#   "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?"),
#  (253, 'Does it matter?'),
#  (254,
#   'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."'),
#  (257,
#   "I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?"),
#  (258, 'Touch of the flu.'),
#  (259,
#   "I'm at a loss, then.  What should we talk about? Your year of absence?"),
#  (261, "Why don't we discuss your driving need to be a hemorrhoid?"),
#  (262, "What's to discuss?"),
#  (263,
#   "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?"),
#  (264,
#   "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good..."),
#  (271, "C'esc ma tete. This is my head"),
#  (272, "Right.  See?  You're ready for the quiz."),
#  (273,
#   "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone."),
#  (274, "That's because it's such a nice one."),
#  (275, 'Forget French.'),
#  (276, 'How is our little Find the Wench A Date plan progressing?'),
#  (277, "Well, there's someone I think might be --"),
#  (280, 'There.'),
#  (281, 'Where?'),
#  (285, 'Yeah'),
#  (286, 'What do you think?'),
#  (287, 'Two legs, nice rack...'),
#  (288, 'Yeah, whatever.  I want you to go out with her.'),
#  (289, "Sure, Sparky.  I'll get right on it."),
#  (290, 'You just said'),
#  (291, 'You need money to take a girl out'),
#  (292, "But you'd go out with her if you had the cake?"),
#  (294, 'You got it, Verona.  I pick up the tab, you do the honors.'),
#  (295, "You're gonna pay me to take out some girl?"),
#  (296,
#   "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend."),
#  (297, 'How much?'),
#  (298, "I can't take a girl like that out on twenty bucks."),
#  (299, 'Fine, thirty.'),
#  (300, "Take it or leave it.  This isn't a negotiation."),
#  (301, "Fifty, and you've got your man."),
#  (304, "I mean Wo-man.  How ya doin'?"),
#  (305, 'Sweating like a pig, actually.  And yourself?'),
#  (306, "There's a way to get a guy's attention."),
#  (307, 'My mission in life.'),
#  (309, 'Pick you up Friday, then'),
#  (310, 'Oh, right.  Friday.'),
#  (311, "The night I take you to places you've never been before.  And back."),
#  (312,
#   'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?'),
#  (313, 'I know a lot more than that'),
#  (319,
#   "I have the potential to smack the crap out of you if you don't get out of my way."),
#  (320, 'Can you at least start wearing a bra?'),
#  (322, "You hate me don't you?"),
#  (323, "I don't really think you warrant that strong an emotion."),
#  (324, "Then say you'll spend Dollar Night at the track with me."),
#  (325, 'And why would I do that?'),
#  (326,
#   'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...'),
#  (327, 'You -- covered in my vomit.'),
#  (328, 'Seven-thirty?'),
#  (330, 'Are you following me?'),
#  (331, "I was in the laundromat. I saw your car. Thought I'd say hi."),
#  (332, 'Hi'),
#  (333, "You're not a big talker, are you?"),
#  (334,
#   "Depends on the topic. My fenders don't really whip me into a verbal frenzy."),
#  (335, 'Hey -- do you mind?'),
#  (336, 'Not at all'),
#  (338, 'My insurance does not cover PMS'),
#  (339, 'Then tell them I had a seizure.'),
#  (340, 'Is this about Sarah Lawrence? You punishing me?'),
#  (341, 'I thought you were punishing me.'),
#  (342, "Why can't we agree on this?"),
#  (343, "Because you're making decisions for me."),
#  (344, "As a parent, that's my right"),
#  (345, "So what I want doesn't matter?"),
#  (346,
#   "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it."),
#  (347,
#   'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --'),
#  (349, 'When I shell out fifty, I expect results.'),
#  (350, "I'm on it"),
#  (351, "Watching the bitch trash my car doesn't count as a date."),
#  (352,
#   'I got her under control. She just acts crazed in public to keep up the image.'),
#  (354, 'I just upped my price'),
#  (355, 'What?'),
#  (356, 'A hundred bucks a date.'),
#  (357, 'Forget it.'),
#  (358, 'Forget her sister, then.'),
#  (363, 'You got something on your mind?'),
#  (364,
#   "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?"),
#  (365, 'You have my word.  As a gentleman'),
#  (366, "You're sweet."),
#  (367, 'How do you get your hair to look like that?'),
#  (368,
#   "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment."),
#  (371, 'Say it'),
#  (372, 'What?'),
#  (373, "Whatever the hell it is you're standin' there waitin' to say."),
#  (375, 'What plan?'),
#  (376,
#   'The situation is, my man Cameron here has a major jones for Bianca Stratford.'),
#  (377, 'What is it with this chick?  She have three tits?'),
#  (378,
#   "I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's."),
#  (379, "Dorsey can plow whoever he wants. I'm just in this for the cash."),
#  (380, "That's where we can help you.  With Kat."),
#  (381, 'So Dorsey can get the girl?'),
#  (382,
#   "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl."),
#  (383, 'You two are gonna help me tame the wild beast?'),
#  (384, "We're your guys."),
#  (385, 'And he means that strictly in a non- prison-movie type of way.'),
#  (386, "Yeah -- we'll see."),
#  (388,
#   'This is it.  A golden opportunity. Patrick can ask Katarina to the party.'),
#  (389, "In that case, we'll need to make it a school-wide blow out."),
#  (390, 'Will Bogey get bent?'),
#  (391,
#   "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass."),
#  (394, "It's more"),
#  (395, 'Expensive?'),
#  (396, "Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?"),
#  (397, 'Hopefully.'),
#  (401, 'Sure have.'),
#  (402,
#   "I really, really, really wanna go, but I can't.  Not unless my sister goes."),
#  (403, "I'm workin' on it. But she doesn't seem to be goin' for him."),
#  (404, "She's not a..."),
#  (405,
#   "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies."),
#  (406, "So that's the kind of guy she likes? Pretty ones?"),
#  (407,
#   "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes."),
#  (411, "What've you got for me?"),
#  (412,
#   "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful."),
#  (414, 'What?!'),
#  (415, 'Good enough.'),
#  (416, 'Number one.  She hates smokers'),
#  (417, "It's a lung cancer issue"),
#  (418, 'Her favorite uncle'),
#  (419, 'Dead at forty-one.'),
#  (420, 'Are you telling me I\'m a -  "non-smoker"?'),
#  (421, 'Just for now.'),
#  (424, "He's pretty!"),
#  (425, "Okay!  I wasn't sure"),
#  (426,
#   'Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".'),
#  (427,
#   "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?"),
#  (428, 'Ever been to Club Skunk?'),
#  (429, 'Yeah.'),
#  (430, 'Gigglepuss is playing there tomorrow night.'),
#  (431, "Don't make me do it, man"),
#  (432, 'Assail your ears for one night.'),
#  (433, "It's her favorite band."),
#  (436,
#   'I prefer to think of it simply as an alternative to what the law allows.'),
#  (437, "I'm likin' you guys better"),
#  (441, "Oh my God, does this mean you're becoming normal?"),
#  (442, "It means that Gigglepuss is playing at Club Skunk and we're going."),
#  (443,
#   "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?"),
#  (444, 'What do you think?'),
#  (445,
#   "I think you're a freak.  I think you do this to torture me.  And I think you suck."),
#  (447, "You think this'll work?"),
#  (448, 'No fear.'),
#  (458, 'Always a pleasure, Brucie.'),
#  (459,
#   "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?"),
#  (460, 'Fan of a fan.  You see a couple of minors come in?'),
#  (461, 'Never'),
#  (462,
#   'Padua girls.  One tall, decent body. The other one kinda short and undersexed?'),
#  (463, "Just sent 'em through."),
#  (473, 'hey.  Great show, huh?'),
#  (474, ''),
#  (475, 'Excuse me?'),
#  (476, "That's what you want, isn't it?"),
#  (477, "Do you mind?  You're sort of ruining it for me."),
#  (481,
#   "You know, these guys are no Bikini Kill or The Raincoats, but they're right up there."),
#  (482, 'You know who The Raincoats are?'),
#  (483, "Why, don't you?"),
#  (490, "What'd he say?"),
#  (491, 'Who cares?'),
#  (499, 'You told me that part already.'),
#  (500, "Hell, I've just been going over the whole thing in my head and -"),
#  (502, "I hear you're helpin' Verona."),
#  (503, "Uh,  yeah.  We're old friend*"),
#  (504, 'You and Verona?'),
#  (505, 'What?  We took bathes together when we were kids.'),
#  (508, "You better not fuck this up.  I'm heavily invested."),
#  (509, "Hey -- it's all for the higher good right?"),
#  (511, "You're completely demented."),
#  (512, 'See you next week!'),
#  (517, 'Daddy, I --'),
#  (518, "And where're you going?"),
#  (519,
#   'If you must know, we were attempting to go to a small study group of friends.'),
#  (520, 'Otherwise known as an orgy?'),
#  (521,
#   'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --'),
#  (523, 'Daddy, people expect me to be there!'),
#  (524, "If Kat's not going, you're not going."),
#  (525,
#   "You're ruining my life'  Because you won't be normal, I can't be normal."),
#  (526, "What's normal?"),
#  (527,
#   "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that."),
#  (529, "Can't you forget for just one night that you're completely wretched?"),
#  (530, "At least I'm not a clouted fen- sucked hedge-pig."),
#  (531, "Like I'm supposed to know what that even means."),
#  (532, "It's Shakespeare.  Maybe you've heard of him?"),
#  (533,
#   "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too."),
#  (536, "Oh, God.  It's starting."),
#  (537, "It's just a party. Daddy."),
#  (538, 'Wear the belly before you go.'),
#  (539, 'Daddy, no!'),
#  (540, 'Just for a minute'),
#  (542, 'You are so completely unbalanced.'),
#  (543, 'Can we go now?'),
#  (544, "Promise me you won't talk to any boys unless your sister is present."),
#  (545, 'Why?'),
#  (546, "Because she'll scare them away."),
#  (554, 'Where ya goin?'),
#  (555, 'Away.'),
#  (556, 'Your sister here?'),
#  (557, 'Leave my sister alone.'),
#  (558, 'And why would I do that?'),
#  (564, "What's this?"),
#  (565,
#   '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?'),
#  (566, 'I say, do what you wanna do.'),
#  (567, "Funny, you're the only one"),
#  (571, 'Where did he go?  He was just here.'),
#  (572, 'Who?'),
#  (573, 'Joey.'),
#  (575, 'Hi.'),
#  (576, 'Looks like things worked out tonight, huh?'),
#  (577, 'You know Chastity?'),
#  (578, 'I believe we share an art instructor'),
#  (579, 'Great'),
#  (580, 'Would you mind getting me a drink, Cameron?'),
#  (583, 'Extremely unfortunate maneuver.'),
#  (584,
#   "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?"),
#  (585, "Buttholus extremus.  But hey, you're making progress."),
#  (586, "No, I ' m not."),
#  (589,
#   'So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.'),
#  (590, 'Queen Harry?'),
#  (591,
#   "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff."),
#  (592, 'Neat...'),
#  (593, "My agent says I've got a good shot at being the Prada guy next year."),
#  (595,
#   "He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation."),
#  (596, 'Is he oily or dry?'),
#  (597,
#   "Combination.  I don't know -- I thought he'd be different.  More of a gentleman..."),
#  (598,
#   "Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding."),
#  (599,
#   "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?"),
#  (600,
#   "All I know is -- I'd give up my private line to go out with a guy like Joey."),
#  (601, 'Bianca, I need to talk to you -- I need to tell you --'),
#  (602, "I really don't think I need any social advice from you right now."),
#  (605, "It's about time."),
#  (606, "A deal's a deal."),
#  (607, "How'd you do it?"),
#  (608, 'Do what?'),
#  (609, 'Get her to act like a human'),
#  (610, 'Okay?'),
#  (611, "I'm fine. I'm"),
#  (612, "You're not okay."),
#  (613, 'I just need to lie down for awhile'),
#  (614, "Uh, uh. You lie down and you'll go to sleep"),
#  (615, 'I know, just let me sleep'),
#  (616,
#   'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...'),
#  (619, "Cameron, I'm a little busy"),
#  (620, "It's off. The whole thing."),
#  (621, "What 're you talking about?"),
#  (622, "She's partial to Joey, not me"),
#  (623, 'Cameron -- do you like the girl?'),
#  (624, 'Sure'),
#  (625, 'Then, go get her'),
#  (626, 'This is so patronizing.'),
#  (627, "Leave it to you to use big words when you're shitfaced."),
#  (628, "Why 're you doing this?"),
#  (629, 'I told you'),
#  (630, "You don't care if I die"),
#  (631, 'Sure, I do'),
#  (632, 'Why?'),
#  (633, "Because then I'd have to start taking out girls who like me."),
#  (634, 'Like you could find one'),
#  (635, "See that?  Who needs affection when I've got blind hatred?"),
#  (636, 'Just let me sit down.'),
#  (639, "Why'd you let him get to you?"),
#  (640, 'Who?'),
#  (641, 'Dorsey.'),
#  (642, 'I hate him.'),
#  (643,
#   "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type."),
#  (644,
#   'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?'),
#  (645, 'I thought you were above all that'),
#  (646, 'You know what they say'),
#  (650, 'Kat! Wake up!'),
#  (651, 'What?'),
#  (655,
#   "I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here."),
#  (656, "You're welcome."),
#  (659, 'I have to be home in twenty minutes.'),
#  (660, "I don't have to be home 'til two."),
#  (662, 'Have fun tonight?'),
#  (663, 'Tons'),
#  (668, "And I'm in control of it."),
#  (669, "But it's Gigglepuss - I know you like them.  I saw you there."),
#  (670, 'When you were gone last year -- where were you?'),
#  (671, 'Busy'),
#  (672, 'Were you in jail?'),
#  (673, 'Maybe.'),
#  (674, "No, you weren't"),
#  (675, "Then why'd you ask?"),
#  (676, "Why'd you lie?"),
#  (677, 'I should do this.'),
#  (678, 'Do what?'),
#  (679, 'This.'),
#  (680, 'Start a band?'),
#  (681, "My father wouldn't approve of that that"),
#  (682, "You don't strike me as the type that would ask permission."),
#  (683, 'Oh, so now you think you know me?'),
#  (684, "I'm gettin' there"),
#  (686, "So what ' s up with your dad?  He a pain in the ass?"),
#  (687, "He just wants me to be someone I'm not."),
#  (688, 'Who?'),
#  (689, 'BIANCA'),
#  (690,
#   "No offense, but you're sister is without.  I know everyone likes her and all, but ..."),
#  (693,
#   'I looked for you back at the party, but you always seemed to be "occupied".'),
#  (694, 'I was?'),
#  (695, "You never wanted to go out with 'me, did you?"),
#  (696, 'Well, no...'),
#  (697, "Then that's all you had to say."),
#  (698, 'But'),
#  (699, 'You always been this selfish?'),
#  (716,
#   'You went to the party?  I thought we were officially opposed to suburban social activity.'),
#  (717, "I didn't have a choice."),
#  (718,
#   "You didn't have a choice?  Where's Kat and what have you done with her?"),
#  (719, 'I did Bianca a favor and it backfired.'),
#  (720, "You didn't"),
#  (721, 'I got drunk.  I puked.  I got rejected. It was big fun.'),
#  (723, 'So you got cozy with she who stings?'),
#  (724, "No - I've got a sweet-payin' job that I'm about to lose."),
#  (725, "What'd you do to her?"),
#  (726,
#   "I don ' t know.  I decided not to nail her when she was too drunk to remember it."),
#  (728, 'Hey there.  Tired of breathing?'),
#  (729, 'Hi.'),
#  (730, 'Cool pictures.  You a fan?'),
#  (731, 'Yeah.  I guess.'),
#  (732, 'You think?'),
#  (733, 'Oh yeah.'),
#  (735, 'Macbeth, right?'),
#  (736, 'Right.'),
#  (737, 'Kat a fan, too?'),
#  (738, 'Yeah...'),
#  (740,
#   "She hates you with the fire of a thousand suns .  That's a direct quote"),
#  (741, "She just needs time to cool off I'll give it a day."),
#  (743, "You makin' any headway?"),
#  (744, 'She kissed me.'),
#  (745, 'Where?'),
#  (747,
#   "I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --"),
#  (748, "Enough with the Barbie n' Ken shit. I know."),
#  (750,
#   'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?'),
#  (751, "Well, I guess we're not, since we don't have dates ."),
#  (752,
#   'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.'),
#  (753, "Okay, okay, we won't go.  It's not like I have a dress anyway"),
#  (754,
#   "You ' re looking at this from the wrong perspective.  We're making a statement."),
#  (755, 'Oh, good.  Something new and different for us.'),
#  (756, 'Hey, sweet cheeks.'),
#  (757, 'Hi, Joey.'),
#  (758, "You're concentrating awfully hard considering it's gym class."),
#  (759, 'Listen, I want to talk to you about the prom.'),
#  (760, "You know the deal.  I can ' t go if Kat doesn't go --"),
#  (764, 'Excuse me, have you seen The Feminine Mystique?  I lost my copy.'),
#  (765, 'What are you doing here?'),
#  (766, 'I heard there was a poetry reading.'),
#  (767, "You 're so --"),
#  (768, 'Pleasant?'),
#  (769, 'Wholesome.'),
#  (770, 'Unwelcome.'),
#  (771, 'Unwelcome?  I guess someone still has her panties in a twist.'),
#  (772,
#   "Don't for one minute think that you had any effect whatsoever on my panties."),
#  (773, 'So what did I have an effect on ?'),
#  (774, 'Other than my upchuck reflex? Nothing.'),
#  (775, "You were right. She's still pissed."),
#  (776, 'Sweet love, renew thy force!'),
#  (777, "Man -- don't say shit like that to  me. People can hear you."),
#  (778,
#   'You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.'),
#  (779, "Best case scenario, you're back on the payroll for awhile."),
#  (780, "What's the worst?"),
#  (781, 'You get the girl.'),
#  (798, 'He left!  I sprung the dickhead and he cruised on me.'),
#  (799, 'Look up, sunshine'),
#  (800, "I guess I never told you I'm afraid of heights."),
#  (801, "C'mon.  It's not that bad"),
#  (802, "Try lookin' at it from this angle"),
#  (803, 'Put your right foot there --'),
#  (804, "Forget it.  I'm stayin'."),
#  (805, 'You want me to climb up and show you how to get down?'),
#  (806, 'Maybe.'),
#  (808, 'The Partridge Family?'),
#  (809,
#   'I figured it had to be something ridiculous to win your respect.  And piss you off.'),
#  (810, 'Good call.'),
#  (811, "So how'd you get Chapin to look the other way?"),
#  (812, 'I dazzled him with my wit'),
#  (813, 'A soft side? Who knew?'),
#  (814, "Yeah, well, don't let it get out"),
#  (815, "So what's your excuse?"),
#  (816, 'Acting the way we do.'),
#  (817, 'Yes'),
#  (818,
#   "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change."),
#  (819, "So if you disappoint them from the start, you're covered?"),
#  (820, 'Something like that'),
#  (821, 'Then you screwed up'),
#  (822, 'How?'),
#  (823, 'You never disappointed me.'),
#  (824, 'You up for it?'),
#  (825, 'For. . . ?'),
#  (828, 'State trooper?'),
#  (829, 'Fallacy.'),
#  (830, 'The duck?'),
#  (831, 'Hearsay.'),
#  (832, "I know the porn career's a lie."),
#  (834, 'Tell me something true.'),
#  (835, 'I hate peas.'),
#  (836, 'No -- something real.  Something no one else knows.'),
#  (837, "You're sweet.  And sexy.  And completely hot for me."),
#  (838, 'What?'),
#  (839, 'No one else knows'),
#  (840, "You're amazingly self-assured. Has anyone ever told you that?"),
#  (841, 'Go to the prom with me'),
#  (842, 'Is that a request or a command?'),
#  (843, 'You know what I mean'),
#  (844, 'No.'),
#  (845, 'No what?'),
#  (846, "No, I won't go with you"),
#  (847, 'Why not?'),
#  (848, "Because I don't want to. It's a stupid tradition."),
#  (852, 'Create a little drama?  Start a new rumor?  What?'),
#  (853, 'So I have to have a motive to be with you?'),
#  (854, 'You tell me.'),
#  (855, 'You need therapy.  Has anyone ever told you that?'),
#  (856, 'Answer the question, Patrick'),
#  (857,
#   "Nothing!  There's nothing in it for me. Just the pleasure of your company."),
#  (860,
#   'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."'),
#  (861, 'No...'),
#  (862, 'do you listen to this crap?'),
#  (863, 'What crap?'),
#  (864, "Me.  This endless ...blonde babble. I'm like, boring myself."),
#  (865, 'Thank God!  If I had to hear one more story about your coiffure...'),
#  (866, "I figured you'd get to the good stuff eventually."),
#  (867, 'What good stuff?'),
#  (868, 'The "real you".'),
#  (869, 'Like my fear of wearing pastels?'),
#  (870,
#   'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?'),
#  (871, 'No'),
#  (872, "Okay -- you're gonna need to learn how to lie."),
#  (876, 'Would you rather be ravished by a pirate or a British rear admiral?'),
#  (877, 'Pirate -- no question.'),
#  (878, "Daddy, I want to discuss the prom with you. It's tomorrow night --"),
#  (879, 'The prom?  Kat has a date?'),
#  (880, 'No, but'),
#  (881,
#   "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?"),
#  (882, 'He\'s not a "hot rod".  Whatever that is.'),
#  (883, "You're not going unless your sister goes.  End of story."),
#  (884,
#   "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!"),
#  (886, "They'll dance, they'll kiss, they'll come home.  Let her go."),
#  (887,
#   "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day."),
#  (889,
#   "Listen, I know you hate having to sit home because I'm not Susie High School."),
#  (890, 'Like you care.'),
#  (891,
#   "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s ."),
#  (892,
#   "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t."),
#  (893, 'Joey never told you we went out, did he?'),
#  (894, 'What?'),
#  (895, 'In 9th.  For a month'),
#  (896, 'Why?'),
#  (897, 'He was, like, a total babe'),
#  (898, 'But you hate Joey'),
#  (899, 'Now I do.  Back then, was a different story.'),
#  (900, 'As in...'),
#  (901, 'He said everyone was doing it.  So I did it.'),
#  (902, 'You did what?'),
#  (903,
#   "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me."),
#  (904, 'But'),
#  (905,
#   'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --'),
#  (906, "Why didn't you tell me?"),
#  (907, 'I wanted to let you make up your own mind about him.'),
#  (908,
#   "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage."),
#  (909, "That's not"),
#  (910, "I'm not stupid enough to repeat your mistakes."),
#  (911, 'I guess I thought I was protecting you.'),
#  (912,
#   "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself"),
#  (913,
#   "Not all experiences are good, Bianca. You can't always trust the people you want to."),
#  (914, "I guess I'll never know, will I?"),
#  (917, "What do you wanna watch?  We've got crap, crap, crap or crap"),
#  (918, 'Dr. Ruth?'),
#  (922, "I'm missing something."),
#  (923,
#   "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know."),
#  (924, 'Wow'),
#  (925, "Let's go."),
#  (926, 'Have a great time, honey!'),
#  (927, 'But -- who -- what --?'),
#  (929, 'What just happened?'),
#  (930, 'Your daughters went to the prom.'),
#  (931, 'Did I have anything to say about it?'),
#  (932, 'Absolutely not.'),
#  (933, "That ' s what I thought"),
#  (936, "How'd you get a tux at the last minute?"),
#  (937, "It's Scurvy's.  His date got convicted. Where'd you get the dress?"),
#  (938, "It's just something I had.  You know"),
#  (939, 'Oh huh'),
#  (940, "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong."),
#  (946, 'Have you seen him?'),
#  (947, 'Who?'),
#  (948, 'William - he asked me to meet him here.'),
#  (949,
#   "Oh, honey -- tell me we haven't' progressed to full-on hallucinations."),
#  (952, "You think you ' re the only sophomore at the prom?"),
#  (953, 'I did.'),
#  (957, "My grandmother's ."),
#  (958, 'What?'),
#  (959,
#   "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story."),
#  (960, "That ' s completely adorable!"),
#  (961, 'It gets worse -- you still have your freshman yearbook?'),
#  (973, 'Wait I...'),
#  (974,
#   'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!'),
#  (975, "It wasn't like that."),
#  (976,
#   'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?'),
#  (977, "I didn't care about the money."),
#  (982, 'You looked beautiful last night, you know.'),
#  (983, 'So did you'),
#  (984, 'She okay?'),
#  (985, 'I hope so.'),
#  (986, 'Was that your sister?'),
#  (987, 'Yeah.  She left with some bikers Big ones.  Full of sperm.'),
#  (988, 'Funny.'),
#  (989,
#   "I don't understand the allure of dehydrated food.  Is this something I should be hip to?"),
#  (990, 'No, Daddy.'),
#  (991, 'So tell me about this dance. Was it fun?'),
#  (992, 'Parts of it.'),
#  (993, 'Which parts?'),
#  (994, 'The part where Bianca beat the hell out of some guy.'),
#  (995, 'Bianca did what?'),
#  (996, "What's the matter?  Upset that I rubbed off on her?"),
#  (997, 'No -- impressed.'),
#  (998,
#   "You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game."),
#  (999, 'When I go?'),
#  (1000,
#   "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check."),
#  (1007, 'Let go!'),
#  (1008, 'You set me up.'),
#  (1009, 'I just wanted --'),
#  (1010,
#   'What? To completely damage me?  To send me to therapy forever? What?'),
#  (1011, 'No! I just wanted'),
#  (1017,
#   'Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?'),
#  (1018, 'Just smack her now.'),
#  (1021, 'Is that woman a complete fruit-loop or is it just me?'),
#  (1022, "It's just you."),
#  (1031, 'A Fender Strat. You bought this?'),
#  (1032, 'I thought you could use it. When you start your band.'),
#  (1033,
#   'Besides, I had some extra cash. Some asshole paid me to take out a really great girl.'),
#  (1034, 'Is that right?'),
#  (1035, 'Yeah, but then I fucked up. I fell for her.'),
#  (1040, 'Why is my veggie burger the only burnt object on this grill?'),
#  (1041, 'Because I like to torture you.'),
#  (1042, 'Oh, Bianca?  Can you get me my freshman yearbook?'),
#  (1043, "Don ' t you even dare. . ."),
#  (1044, 'They do to!'),
#  (1045, 'They do not!'),
#  (1051, 'Patrick -- is that- a.'),
#  (1052, 'Perm?'),
#  (1930, 'Is that the man I knew, Treasurer Sanchez?'),
#  (1931, 'Yes, Your Majesty.'),
#  (1942,
#   'Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...'),
#  (1943,
#   'Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.'),
#  (1947, "God... That's in a week!"),
#  (1948, "That's what it says."),
#  (1949, 'How did you manage it?'),
#  (1950,
#   'With some difficulty.  I had to promise them you were not a total fool.'),
#  (1951, 'Why do you wish to sail west?'),
#  (1952,
#   'To open a new route to Asia.  At the moment there are only two ways of reaching it...'),
#  (1957, 'How can you be so certain?  The Ocean is said to be infinite.'),
#  (1958,
#   'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.'),
#  (1959, 'How can you be so certain?'),
#  (1960, 'The calculations of Toscanelli Marin de Tyr, Esdras...'),
#  (1961, 'Esdras is a Jew.'),
#  (1962, 'So was Christ!'),
#  (1963,
#   "Two minutes... and already you're a dead man.  Don't let passion overwhelm you, Colon."),
#  (1964, "I'll try to remember that, Marchena..."),
#  (1965, 'Father Marchena!'),
#  (1966, 'Passion is something one cannot control!'),
#  (1967, 'You get so carried away when you are being contradicted!'),
#  (1968, "I've been contradicted all my life... Eternity!"),
#  (1969, 'Only God knows the meaning of such words, my son.'),
#  (1979, 'I could be gone for years.'),
#  (1980, 'I know.'),
#  (1981, "I haven't given you much of a life."),
#  (1982,
#   "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving..."),
#  (1983, 'Are we going to argue?'),
#  (1984, "I'd love to argue with you sometimes.  But you're never here!"),
#  (1985, 'Perhaps I was never meant to live with a woman...'),
#  (1986, 'I find that hard to believe.'),
#  (1989, 'You say Asia can be found by sailing west?'),
#  (1990,
#   'Yes, your Eminence.  The voyage should not take more than six or seven weeks.'),
#  (1991,
#   'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?'),
#  (1992, 'I am, Your Eminence'),
#  (1993,
#   'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.'),
#  (2005,
#   'Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.'),
#  (2006, 'Excellency, you are right.'),
#  (2010,
#   'Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.'),
#  (2011, 'Your life, and that of others!'),
#  (2012, 'If they agree to follow me, yes.'),
#  (2014,
#   'Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.'),
#  (2015, 'Is that all that interests you? Gold?'),
#  (2016,
#   'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.'),
#  (2019,
#   'If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?'),
#  (2020, "Did He not choose a carpenter's son to reveal Himself to the world?"),
#  (2022, "Don't you realize your words could be considered heretical?"),
#  (2023, 'Blind faith is what I consider heresy!'),
#  (2024, 'Asia can be found to the west -- and I will prove it.'),
#  (2025, 'IF-GOD-WILLS-IT!'),
#  (2027,
#   "The State has some reason to be interested in this man's proposition, Your Eminence..."),
#  (2028, 'The Judgment is ours!'),
#  (2029,
#   'Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.'),
#  (2030,
#   'He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?'),
#  (2031,
#   'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.'),
#  (2037, "You mustn't give way to despair. You must wait."),
#  (2038,
#   "Wait!  I've waited seven years already!  How much longer do you want me to wait?"),
#  (2039, 'If God intends you to go, then you will go.'),
#  (2040, 'Damn God!'),
#  (2041, 'Colon!'),
#  (2042,
#   'Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!'),
#  (2045, 'All of them!  Just lies!'),
#  (2046, "Colon!  Don't!"),
#  (2064, 'Where can I meet this man?'),
#  (2065, 'Immediately.'),
#  (2071,
#   'I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.'),
#  (2072,
#   'No more than the woman who said she would take Granada from the Moors.'),
#  (2073, 'The ocean is uncrossable?'),
#  (2074, 'What did they say about Granada before today?'),
#  (2075, 'That she was impregnable.'),
#  (2076, 'I cannot ignore the verdict of my council.'),
#  (2077, 'Surely you can do anything you want.'),
#  (2079, 'May I speak freely?'),
#  (2080, 'You show no inclination to speak otherwise!'),
#  (2081,
#   'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...'),
#  (2082, 'A woman?'),
#  (2085, 'How old are you, Senor Colon?'),
#  (2086, 'Thirty seven, Your Majesty... And you?'),
#  (2103, 'No...'),
#  (2104, 'No?'),
#  (2105,
#   'NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!'),
#  (2106,
#   'I remind you, Senor Colon, that you are in no position to bargain with me.'),
#  (2107, "I'm not bargaining!"),
#  (2108, 'Then you are too ambitious.'),
#  (2109,
#   'And were you never ambitious, Excellency?  Or is ambition only a virtue among the nobles, a fault for the rest of us?'),
#  (2110,
#   "If you won't accept our proposal, we'll simply find someone who will."),
#  (2112, 'You were right, Don Sanchez... His demands could never be granted.'),
#  (2113, 'Never, Your Majesty.  Although...'),
#  (2115, '... Into a monk...'),
#  (2116, "Yes.  It would be a pity, wouldn't it?  Call him back!"),
#  (2118, 'She said yes.'),
#  (2119, 'Thank God...'),
#  (2121, "I'm not asking you to swear to anything."),
#  (2122, "I don't want you to wait for me."),
#  (2123, "That's something you can't decide."),
#  (2127, 'I want to go with you!'),
#  (2128, "There'll be a time."),
#  (2129, 'You promise?  Do you swear on St. Christopher...?'),
#  (2130, 'Do you swear on all the Holy Saints in heaven?'),
#  (2131, 'Yes... Yes, I do... On all of them!'),
#  (2132, 'In Nomine Patris et Filius, et Spiritus Sancti.'),
#  (2133, 'Forgive me, Father.  For I have sinned.'),
#  (2134, 'I am listening, my son.'),
#  (2135,
#   'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.'),
#  (2136, 'What are you saying?'),
#  (2137, 'I lied.  The journey will be longer than I said.'),
#  (2138, 'How long?'),
#  (2139, 'I am not sure... It could be twice the distance.'),
#  (2140,
#   'May God forgive you...!  You must tell them!  You must tell your men!'),
#  (2141,
#   "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me..."),
#  (2142,
#   "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will."),
#  (2143, 'You are bound by an oath, Father.'),
#  (2144, 'I believed in you...'),
#  (2145, 'Give me absolution.'),
#  (2154, 'Due west, Captain Mendez.  And may God be with us...'),
#  (2155, 'God be with us admiral.'),
#  (2157,
#   "Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago..."),
#  (2158, 'And what do you think Mendez?'),
#  (2159,
#   "Well, I surely know what a quadrant is!  But I've never seen it used at night before."),
#  (2160, 'Come over here.'),
#  (2164, 'What do you read?'),
#  (2165, 'Twenty eight.'),
#  (2170, 'I never seen heat like this!  Not even in Las Minas!'),
#  (2171, "The water's going putrid in the barrels."),
#  (2172,
#   "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!"),
#  (2173, 'What are you listening to, chicken ass?'),
#  (2174, "Ah, leave him alone.  He's doing no harm."),
#  (2175, "With a face like that?  I don't want you looking at me.  You hear?"),
#  (2176, "He's the devil's child..."),
#  (2177, "We'll all go crazy..."),
#  (2179, 'We should have seen land.'),
#  (2180, "We left three weeks ago, Alonso. Can't be that near."),
#  (2181,
#   "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign..."),
#  (2196, "You lied!  You cheated!  We're way past 750 leagues!"),
#  (2197, 'Six days ago, yes.'),
#  (2198, 'You must be mad...!'),
#  (2199, 'We have to keep the hopes of these men alive!'),
#  (2200, "We're on the verge of a mutiny, Colon!"),
#  (2201, "You think I don't know that?"),
#  (2202, "We're lost!"),
#  (2203, 'The land is there.  I know it!'),
#  (2204,
#   "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!"),
#  (2205,
#   'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!'),
#  (2206, 'Jesus Maria!  I should have never listened to you!'),
#  (2207, 'You never did.  You did all the talking for both of us, remember?'),
#  (2208, 'You bloody...'),
#  (2209,
#   'Pinzon, Pinzon... All we can do now is go forward!  Think about that!'),
#  (2210, 'You tell that to them!'),
#  (2211, "You're right.  Let the men decide."),
#  (2237, 'Say not here!  Cuba!'),
#  (2238, 'What is it?  A tribe?  An island?'),
#  (2239, 'Island.  Far.'),
#  (2248, 'You come!  You speak first!'),
#  (2249, 'Tell the Chief we thank him.'),
#  (2250, 'Chief knows.'),
#  (2251,
#   'Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.'),
#  (2253, 'Chief says -- how many?'),
#  (2254, 'Thousands.'),
#  (2255, 'Why?'),
#  (2256, 'To bring the word of God.'),
#  (2257, 'Chief says -- he has a God.'),
#  (2258, '... and also to bring medicine.'),
#  (2259, 'Chief says...'),
#  (2260, 'He has medicine.  Tell him we admire his people.'),
#  (2274, "It won't be easy to get rid of your prophet now, Don Sanchez."),
#  (2275,
#   'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.'),
#  (2277,
#   "And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin."),
#  (2278, 'The Indians have no such word, Don Moxica.'),
#  (2279, 'Do they have such thoughts?'),
#  (2280, 'They come and go as naked as the day God created them...'),
#  (2281,
#   "They don't see sin in their nakedness.  They live according to nature, in a never ending summer. The islands are covered with trees, filled with blossoms and fruits. And..."),
#  (2282, 'Forgive me, Don Colon.  But what about gold?'),
#  (2286, 'You defend yourself admirably...'),
#  (2287, '... for a commoner?'),
#  (2290,
#   'I understand that you will soon be appointing Governors for the islands?  Is it not so?'),
#  (2291,
#   'Forgive me, Don Bobadilla -- those positions have already been taken.'),
#  (2292, 'May I ask by whom?'),
#  (2293, 'Bartolome and Giacomo Colon.'),
#  (2295,
#   'But we do have a lack of notaries. You should contact my administration.'),
#  (2296, 'Don Bobadilla is already a judge, my Dear Don Cristobal.'),
#  (2297, 'Good!  We are also in need of judges.  Except there are no thieves!'),
#  (2299, 'You seem to have a special talent for making friends.'),
#  (2300, 'What...?  Do I have so many already?'),
#  (2301,
#   'To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.'),
#  (2318, 'Beatrix, I want to ask you something.'),
#  (2319, "You don't usually ask."),
#  (2320,
#   'I can arrange for the Queen to take Fernando and Diego into her service.'),
#  (2328, 'We lost cousins, friends.  We will wash this in blood.'),
#  (2329,
#   "If you want to keep your head on your shoulders, you'll do as I say."),
#  (2331,
#   'You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?'),
#  (2332, "We don't need to know."),
#  (2333,
#   'We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.'),
#  (2341,
#   'We will work with his people.  We want peace.  Ask the Chief if he understands?'),
#  (2342, 'He understands.'),
#  (2343, 'Ask him if he will help.'),
#  (2345, "We can't raise the wheel without it."),
#  (2346, "My horse doesn't work."),
#  (2347, 'Don Moxica -- we all have to work.'),
#  (2348, 'You did not hear me, Don Colon.  Not my horse.'),
#  (2376,
#   'Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.'),
#  (2377,
#   "We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time."),
#  (2386,
#   'In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!'),
#  (2387, 'Savagery is what monkeys understand.'),
#  (2388,
#   "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?"),
#  (2389, 'You will regret this.'),
#  (2393, 'You have to find them, Utapan.  Look what they did!'),
#  (2394, 'You did the same to your God!'),
#  (2409,
#   "Utapan, won't you speak to me?  You used to know how to speak to me."),
#  (2410, 'You never learned how to speak my language.'),
#  (2414,
#   '... But there is worse.  He ordered the execution of five members of the nobility...'),
#  (2415, 'Is this true, Brother Buyl?'),
#  (2417, 'Then, what do you suggest, Don Sanchez?'),
#  (2418, 'He must be replaced.'),
#  (2419, 'And who would you think of, for such a task?'),
#  (2421, 'Don Alonso de Bobadilla.'),
#  (2422, 'Yes... I remember...'),
#  (2423, 'My letters of appointment.'),
#  (2424, 'Appointment to what?'),
#  (2425, 'Viceroy of the West Indies.'),
#  (2426, 'Congratulations.  Then I am free to search for the mainland.'),
#  (2429, 'How far from here?'),
#  (2430,
#   'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.'),
#  (2431,
#   'How could I be?  The mainland has been found.  Exactly as I said it would.'),
#  (2432, 'I am afraid this is not the worst news.'),
#  (2439, 'I have to explore the mainland.'),
#  (2440, 'This time with me!'),
#  (2456,
#   'But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.'),
#  (2457, 'Thank you.'),
#  (2458,
#   "There is one thing I'd like to understand... Why do you want to go back, after all this?"),
#  (2459,
#   'Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.'),
#  (2460, 'I know, I should not tolerate his impertinence.'),
#  (2461, 'Then why?'),
#  (2462, 'Because he is not afraid of me.'),
#  (2463, 'All I have to do is call the guards.'),
#  (2464, 'Call them.'),
#  (2465, 'I am not afraid of you.  You are nothing but a dreamer.'),
#  (2466, 'Look out of that window.'),
#  (2467, 'What do you see?'),
#  (2468, 'Roofs... towers, palaces... spires...'),
#  (2469, 'All of them created by people like me.'),
#  (2471,
#   "God... you're so beautiful!  I can't believe no other man has ever taken you away from me..."),
#  (2472, "They tried... but I didn't let them."),
#  (2473, 'They took everything...'),
#  (2474,
#   "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier..."),
#  (2484, 'How are you feeling, Fernando?'),
#  (2485, 'Not bad.'),
#  (2490, "What's he doing?"),
#  (2491, "He's drawing an isthmus... He's saying we're on an isthmus."),
#  (2492, "We can't be."),
#  (2500, 'Father...'),
#  (2501, 'There must be a passage to that other ocean.'),
#  (2522, 'You can see for yourself.'),
#  (2523, 'What a tragedy... what a waste of a life...'),
#  (2524,
#   'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.'),
#  (2525, "I suppose we're both old men now."),
#  (2526, "You'll always be older than me, Father."),
#  (2531, 'I have to disagree.'),
#  (2532, 'I knew you would.'),
#  (2533, 'New worlds create new people.'),
#  (2534, 'Oh?  So you are a new man?'),
#  (2535,
#   "I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!"),
#  (2537, "Can't you stay with us a little?"),
#  (2538, 'I am busy inside.'),
#  (2539, 'What is it, now?  Tell me...'),
#  (2540,
#   "I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you."),
#  (2541, 'What are you listening to?'),
#  (2542, "I am not listening, Father.  But I can't help hearing."),
#  (2547, 'What does he say?'),
#  (2548, 'He asks when he can come to visit you.  He left his address.'),
#  (2549, 'He never had one... except aboard my ships!'),
#  (2550,
#   'I want you to tell me everything you remember, Father.  From the beginning.  Everything.'),
#  (2551, "Really?  God... I wouldn't know where to start... and yet..."),
#  (2552, 'Tell me the first thing that comes to your mind.'),
#  (2557,
#   "Just do what I do.  Say the same thing I say.  Don't open your mouth."),
#  (2558, 'Okay.'),
#  (2559, "Don't fool around."),
#  (2560, 'Okay.'),
#  (2561, 'Did you hear what I said?'),
#  (2562, 'I want to document my trip to America.'),
#  (2563, 'Next.  Could I see your documents, please?'),
#  (2564, 'Yes sir.'),
#  (2565, 'What is your intended purpose of your visit to the United States?'),
#  (2566, 'Two weeks holiday.'),
#  (2567, 'How much money are you carrying with you?'),
#  (2568, 'I have five-hundred dollars.'),
#  (2569, 'Can you show me?  Sir, no cameras in the FIS area!'),
#  (2570, 'Is he with you?  Are you travelling together?'),
#  (2571, 'Yes.'),
#  (2572, 'Please join us.  Come on forward.'),
#  (2573, 'Is there a problem?'),
#  (2574,
#   "No, you're travelling together.  I want to talk to you together.  Hi, how are you?  Can I take a look at your documents?  Are you related?"),
#  (2575, "Yes...he's my friend."),
#  (2576,
#   "Okay.  You're a Czech national and you're a Russian national.  How do you know one another?"),
#  (2577, 'We are both from Prague.'),
#  (2578, 'How long are you planning to stay?'),
#  (2579, 'Two weeks.'),
#  (2580, "I'd like to speak for himself, okay?"),
#  (2581, "He doesn't speak English."),
#  (2582, 'I speak English.'),
#  (2583,
#   "Then answer my questions.  Where were you planning to stay during the two weeks that you're here?"),
#  (2584, 'New York.'),
#  (2585,
#   "Yes, we're in New York now.  But where are you planning to stay in New York?"),
#  (2586, 'A cheap hotel.'),
#  (2587, 'What are you coming here to do?'),
#  (2588, "I'm here for movies."),
#  (2589, 'Movies...to be in the movies or to see movies?'),
#  (2590,
#   'Yes.  No.  Both.  When I was a boy, I see movie at school called "It\'s a Wonderful Life" directed by Frank Capra. Ever since I want to come to America. Land of the free.  Home of the brave.  A land where anyone can be anything. As long as they are white.'),
#  (2591, 'Excuse me?'),
#  (2595,
#   "So we're waitin' to hit this warrant - we got Emergency Service with the heavy weapons standin' by - ready to go.  I say, lemme get a cigar outta the car.  I go to get the cigar and BOOM!  All the sudden I turn around and a kid with a shotgun let one go.  Right where I was standin'.  That coulda been it.  I coulda had my head blown off and for what?  Some stupid kid got panicky, takes the safety off and it's over.  If I hadn't gone back for that cigar - for a bad habit - I would've had my head blown off."),
#  (2596, 'Jesus Christ.'),
#  (2599, 'Coffee for me, I gotta slow down.'),
#  (2600, 'Vodka tonic.'),
#  (2601, 'Maybe you could just put in a shot of Martell?'),
#  (2602, "It was freaky, I'll tell you.  Stupid kid."),
#  (2603,
#   "What's the kid gonna say - sorry? Meanwhile I'm not here anymore. Like last week - we were at the morgue and this guy was all chopped up - spleen here - liver there - his heart in a pan. Six hours ago this guy was walkin' his dog or buyin' a quart of milk.  Who knows?  But some kid's robbed him for $3 or some shit and shot him and now you can't tell if he's a piece of beef or a human being and I'm thinkin' that's me. Sooner or later.  That's me."),
#  (2604, "Sooner or later that's everybody."),
#  (2605,
#   'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.'),
#  (2606, "I think you're getting a little moody there, Eddie."),
#  (2607, "I'm not moody."),
#  (2608, "Isn't he a little moody?"),
#  (2609, "Of course he's moody.  He thinks he's in love."),
#  (2610, 'In love?  With who?'),
#  (2611, 'How old are your kids?'),
#  (2612,
#   "My kids?  Let's see...Susan's 15. Aundrea's 9.  Don't tell me you're thinking about having a kid!  How old are you?  Never mind. Let me just tell you this: Every stupid cliche you hear about kids - they change your life, they make you a better person, they make you whole...  It's all true!  Before I had kids when friends talked about their kids, I wanted to vomit.  Now -- I get it.  Am I right, Leon?"),
#  (2614, 'Yeah?'),
#  (2615, "Paulie, you've got kids, right?"),
#  (2621,
#   'Okay.  You work in a vodka factory.  I understand that.  And what kind of work do you do?'),
#  (2622, 'I am butcher.'),
#  (2623, "You're a butcher?  What do you use pig intestines for?"),
#  (2624, 'You stuff sausage in it.'),
#  (2625, 'And what do you do with the bones?'),
#  ...]

# %%
# 会話のペアごとに辞書を作る { 会話セットid: [会話リスト] }
conves_dict = {}
counter = 1
conves_ids = []
for i in range(1, len(sorted_chats)+1):
    if i < len(sorted_chats):
        if (sorted_chats[i][0] - sorted_chats[i-1][0]) == 1:
            # 1つ前の会話の頭の文字がないのを確認
            if sorted_chats[i-1][1] not in conves_ids:
                conves_ids.append(sorted_chats[i-1][1])
            conves_ids.append(sorted_chats[i][1])
        elif (sorted_chats[i][0] - sorted_chats[i-1][0]) > 1:            
            conves_dict[counter] = conves_ids
            conves_ids = []
        counter += 1
    else:
        pass

# %%
conves_dict
# Out:
# {196609: ["Drink up, Charley. We're ahead of you.",
#   "I'm not thirsty.",
#   "After what we been hearing about your brother, I thought your throat'd be kind of dry.",
#   "So they're walking along and smiling. That doesn't mean he's going to talk. There's no evidence until he gives public testimony.",
#   "Thanks for the legal advice, Charley. That's what we always kept you around for.  Now how do we keep him from giving this testimony? Isn't that the er as you put it main order of business?",
#   'He was always a good kid. You know that.'],
#  3: ['Did you change your hair?', 'No.', 'You might wanna think about it'],
#  283990: ['I believe I have found a faster way.', 'Hmmm?', 'Uh-uh.'],
#  294913: ["I got all I could get which was 750,000 shares plus 5000 March 50 calls. Average price of $47 a share And $4 per contract for the call. I just wish I could've got more.",
#   "Don't expect to get it all, sport, you'll burn out. First rule of business is never get emotional about stock, clouds the judgment. Where do we stand?"],
#  192039: ['What about one forty-two.',
#   "You can have the one next to yours if you want. One twenty.  It ain't took.",
#   'No, one forty-two.',
#   "That's got two double beds."],
#  262154: ['Ever take a look at the women who work in pet stores?  Wow.',
#   'Good luck.',
#   'Jesus, are you gay enough or what.',
#   'Very attractive.  Good idea.  Now I <u>really</u> want to fuck you.',
#   "... you can always tell the ones who'll do anal.",
#   "Kinda makes you wonder why more people don't put a bullet through their fuckin' skulls, doesn't it.",
#   'Looks like they just airbrushed the dick out of his mouth.',
#   "Why don't they have TV shows about people whose daily lives you'd be interested in watching.  Y'know.  Like SKINNY LITTLE WEAKLING.  Or BIG FAT GUY.  SICK OLD MAN. FAMILY OF LOSERS.  Wouldn't that be good?",
#   "Two blacks and a Mexican in a car.  Who's driving?",
#   "I don't know.",
#   'The L.A.P.D.'],
#  65548: ['I think we went the wrong way.',
#   'Oh, you think?',
#   'The map said to go left.',
#   'Yeah and if you turned it around it would say to go right.',
#   'Oh yeah.',
#   'Frankie, come in. Good to see you.      You want something?',
#   "No, I'm good, Angelo.",
#   'I understand Bobby Beans came to see you today.',
#   'Yeah. Seems Maranzano wants to talk about buying the Merchant Street warehouse.',
#   'And?',
#   "And nothing.     He's just feeling us out.",
#   "He's trying to get a foot hold in our territory.",
#   "He sticks his toes in the water again, we'll cut 'em off.",
#   'Business must be good if he can afford to buy up useless property.',
#   'I heard this quarter his profits are gonna be supernumerary.',
#   "They're gonna be what?",
#   'Supernumerary. It means better than expected.',
#   'Good word.'],
#  196621: ["This girl and the Father got their hooks in him so deep he doesn't know which end is up anymore.",
#   "I ain't interested in his mental condition. All I want to know is, is he D 'n D or is he a canary?",
#   'I wish I knew.',
#   'So do I, Charley. For your sake.',
#   'What do you want me to do, Johnny?',
#   'Very simple. Just bring him to... that place we been using. Mac, you take care of the details. Call Gerry G. in if you think you need him.',
#   "Gerry G!! You don't want to do that, Johnny! Sure the boy's outa line, but he's just a confused kid.",
#   "Confused kid? First he crosses me in public and gets away with it and then the next joker, and pretty soon I'm just another fellow down here.",
#   "Johnny, I can't do that. I can't do that, Johnny.",
#   "Then don't.",
#   'But my own kid bro',
#   "This is for you to figure out. You can have it your way or you can have it his way.  But you can't have it both ways.  Am I right, Sonny?"],
#  196623: ["Gee, Charley, I'm sure glad you stopped by for me. I needed to talk to you. What's it they say about blood, it's ",
#   'Thicker than water.'],
#  65553: ['Someone else coming?',
#   "Nah, that's just Tony's way of telling me Judge Judy starts in ten minutes. You ever watch it?",
#   'Uh, no --',
#   'You should. You can learn a lot about the criminal justice system on a program like that. Very informative. Stay and watch it with me.',
#   "You know, I'm kind of tired. I'm just gonna go home if it's all the same to you."],
#  131090: ['You talk kind of funny, but I like it.',
#   'I used to be an actress.',
#   'Yeah? What do you do now?',
#   "I'm a college girl. Two days a week, Tuesdays and Thursdays, I go to college.",
#   "You don't look like a college girl.",
#   "I'm the emancipated type. Real emancipated.",
#   "No, I didn't mean that -- whatever that means. I mean, you just don't look young enough.",
#   "I'm not.",
#   'So why go to college?',
#   "I've got nothing else to do on Tuesdays and Thursdays.",
#   'What do you do on the other days?',
#   'I drink.',
#   'Hey!',
#   "No. No more. I'm getting sleepy.  Thank you very much, Mr...?",
#   'Eddie. The name is Eddie.',
#   'The name should be Eddie. What should my name be?',
#   "I don't know. Whatever you like it to be.",
#   "I like it to be what it is. It's Sarah. That's a biblical name. You want to know its meaning?",
#   'I could always get us a bottle.',
#   'No.',
#   'Fifth of scotch?',
#   'What do you want me to do, just step out in the alley? Is that it?',
#   "No. I'll take you home."],
#  19: ['I missed you.',
#   'It says here you exposed yourself to a group of freshmen girls.',
#   'It was a bratwurst.  I was eating lunch.',
#   'With the teeth of your zipper?',
#   'You the new guy?',
#   'So they tell me...',
#   "C'mon.  I'm supposed to give you the tour.",
#   'So -- which Dakota you from?',
#   "North, actually.  How'd you   ?",
#   'I was kidding. People actually live there?',
#   "Yeah.  A couple.  We're outnumbered by the cows, though.",
#   'How many people were in your old school?',
#   'Thirty-two.',
#   'Get out!',
#   'How many people go here?',
#   'Couple thousand. Most of them evil'],
#  272783: ['Have you seen this?', "What, I'm working, what?"],
#  21: ["That I'm used to.",
#   'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.'],
#  298339: ['Great.',
#   'From my wise, albeit youthful, vantage point, the world is your oyster. You scored big.',
#   'You got everything you ever wanted.',
#   'Except the girl. The only one that really mattered.'],
#  65559: ["Oh Frankie, what's this I hear about your brother?",
#   'He missed three weeks.',
#   "Your own brother? You couldn't send someone else to do it?",
#   'I did. Joey "Two Tons" and Nicky "The Rake" did the deed.',
#   'But you were there?',
#   'Angelo, we live and die by the rules we make. We are men of honor, but honor without respect is a... horse-less carriage.'],
#  131096: ['Hey, uh, mister? Hey, okay if I grab a cue?',
#   "Hey, you're Eddie Felson, aren't you?",
#   "Who's he?",
#   'Now, look, fella, I saw you playing at Ames the other night.',
#   "Hey, I'll tell you what -- I'll play you jack-up pool -- just keep one hand in my pocket.",
#   "Oh man, you're way out of our league."],
#  27: ['That girl -- I --',
#   'You burn, you pine, you perish?',
#   'Who is she?',
#   "Bianca Stratford.  Sophomore. Don't even think about it",
#   'Why not?',
#   "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility."],
#  65566: ["We've got to be careful not to use our real names while we're in here.",
#   'Good idea.',
#   "I'll be Elvis and you--",
#   '-- I want to be Elvis.',
#   "It's my idea.",
#   "C'mon, I look more like Elvis than you do.",
#   'Okay.   You can be Elvis.'],
#  294606: ["No, I didn't think so.",
#   "Leav't alone.  Wha'd television ever do to you?  Ate your <u>life</u>, ruin'd your <u>Culture</u>, but...",
#   '<u>IT DESTROYED THE ELECTORAL PROCESS</u>.',
#   'Come on.',
#   '...where?',
#   'Come on.',
#   'Y\'know what else bothers me?  "Shh lil baby, don\' saya word, papa\'s gon buy you a mocking bird..."  The baby don\'say a word, WHAT THE FUCK IS THE MOTHERFUCKING MOCKING BIRD GONE SAY?  You follow me...?',
#   'Get on your feet, boy.',
#   'Uh huh...why?',
#   "We're going home.  We're going home together...",
#   "We have no home.  We're vagrants.  N'each man's hand's against us.  We killed Old Shoe...  We killed the Schuster...spend our life in a packingcrate...Where are you <u>going</u>...?",
#   'Come on, Pal, come on Willie, come on, Old Shoe...',
#   'Just want to take a nap.',
#   "He's not dead, Ronnie.  He's just a little understandab1y, <u>fatigued</u>.  Let's get him to some help...",
#   '...gimme some help...',
#   "That's right, we'll take a nap.  We'll get you to Washington, we'll get you Back to your Buddies, and...",
#   '...just want to Get Back to the Beans...',
#   "Come on, you fucking sissy, you think this is tough? Try show-business.  1970-1990, n'ybody I worked with, y'could of bottled their piss n'sold it in the <u>ghettos</u>...  Come on, Pal...",
#   "I'm tired.",
#   "Finish Strong!  Are you <u>nuts</u>?  Are you nuts?  This's Pennies from <u>Heaven</u>... on his triumphal return home, Old Shoe, his Plane Forced Down...AND YET...",
#   "He's supposed to be flying in from Europe.",
#   "We'll deal with that when we come to it.  <u>This</u> is producing.  <u>This</u> is what they pay off on...come on, Pal, Boots and Saddles...",
#   '...his Triumphal Plane.  Shot Down.',
#   "Shot down, Forced down...  You guys are <u>missing</u> it... You're missing the <u>opportunity</u>"],
#  65569: ['There has to be.',
#   "I'm telling you I've pulled out everything in the safe. There aren't any jewels.",
#   'There must be half a million dollars here though.'],
#  34: ["Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#   'Expressing my opinion is not a terrorist action.',
#   "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#   'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#   'The point is Kat -- people perceive you as somewhat ...',
#   'Tempestuous?',
#   'No ... I believe "heinous bitch" is the term used most often.'],
#  283995: ['It would appear we are too heavy.',
#   'It must be all those marsh melons.',
#   'Spock... the booster rockets.',
#   'If I activate them now, Captain, we will be propelled upward at an unbelievable rate.',
#   'Fire the rockets!'],
#  294918: ["I'll be right there, fix them a drink.",
#   "...we have 37.2 million invested. At this point, we're up 3.1 million and some change. If it goes to 75 bucks we can clean close to 12 mill.",
#   "You're walking between the raindrops kid. I expect Sir Larry is choking on his royal chamber pot by now.",
#   'My firm needs your signature on these option agreements tonight, sir, otherwise we could take a real bath tomorrow.',
#   "...Can't it wait? I'm good for it.  ...Awright. Come out, get the directions from Natalie and hurry up."],
#  250961: ['Hey.',
#   "Hey. What's up?",
#   "There's something I need to talk about with you.",
#   'What?',
#   'There are some rumors...',
#   'Like what?',
#   'You know...Stanley...',
#   'Oh.',
#   "And like, don't take this the wrong way...I mean, I'm cool...but...you know...I've got a good reputation at school and, well...I really don't want it ruined.",
#   "No prob. I'm cool.",
#   'Thanks, Scoob.'],
#  262183: ["-- they want Southern, I do Southern, they want Midwest, I do Midwest, they want tall, blonde, and twenty-two, I'm shit out of luck.  One thing I can't do is English. Americans can't.  Shouldn't even try. And Laurence Olivier couldn't do us.",
#   'You ever been to London?',
#   'Only in the movies.',
#   "I've 'ardly ever left it.",
#   "Yeah, well, you're here now --  -- where <u>h</u>urricanes <u>h</u>ardly ever <u>h</u>appen.",
#   "I've got the hang of the driving.  Found this place all right.",
#   'Stick with me, kid.  Looks big when you get here but you can cover it in five minutes.',
#   'Not that I recall.',
#   'What about your grandmother?',
#   'Nah -- she was married to me grandad -- he was as bent as a boomerang -- used to make knuckle-dusters down the shop. Crafty old sod.',
#   'He alive to see this?',
#   'Dropped dead in the stalls in the Odeon, Muswell Hill.  Watching Doris Day.',
#   "What'd your father do?",
#   'Black market during the war.',
#   "I guess you're just habitual.",
#   'You sound like my fucking probation officer.',
#   "Won't he be looking for you about now?",
#   "Good luck to him.  He couldn't find his prick if he didn't wear Y-fronts.",
#   "Minor officials bother you, don't they?",
#   "Do us a favor.  Can't even go have a slash without 'em saying, what're you going in there for?"],
#  65576: ["We have a problem. Problem isn't the right word. Dilemma. No that really doesn't describe --  Do you know who that is?",
#   'Mr. Taylor?',
#   "No, that's not Mr. Taylor.",
#   "It's not?",
#   "That's Frankie Zammito.   The Under boss of the Chicago Mafia.",
#   'Why would they want us to rob the Mafia?',
#   ''],
#  131114: ['Why did you do that?',
#   'I wanted to see what kind of a day it is.',
#   'A day like any other. People come, people go.',
#   'Give me a drag.',
#   'What time is it?',
#   "Eleven o'clock... I'll be back later.",
#   'Why?',
#   'Come here.',
#   "Oh, you need a shave. You mustn't go looking like that. There's a razor and shaving cream in the bathroom. Compliments of the house.",
#   'What did you say that for, Sarah?',
#   'How did you know my name was Sarah?',
#   'You told me.',
#   "I lied. When I'm drunk I lie.",
#   "Okay. So what's your name today?",
#   "Sarah.  Eddie, look. I've got troubles, and I think maybe you've got troubles. Maybe it'd be better if we just leave each other alone.",
#   "I got my things over at the hotel. I'll bring them over later...  Come here.",
#   "I'm not sure... I don't know.",
#   'Well, what do you want to know? And why?'],
#  46: ["Who's that?",
#   'Patrick Verona   Random skid.',
#   "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#   "I'm sure he's completely incapable of doing anything that interesting.",
#   'He always look so',
#   'Block E?',
#   'Mandella, eat.  Starving yourself is a very slow way to die.',
#   'Just a little.',
#   "What's this?",
#   'An attempted slit.',
#   "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#   "But imagine the things he'd say during sex."],
#  131119: ['Where you been all day?',
#   "At school. It's Thursday.",
#   'Oh, I forgot.',
#   "You were asleep when I left. I didn't want to wake you. Did you go out?",
#   'Yeah, I went out for a couple of hours.'],
#  293381: ['What about you, Manuel?',
#   "I'm only good at making people laugh.",
#   "That's all right; we all laugh here, but not at you; I'll see to that."],
#  196657: ['River Street? I thought we was going to the Garden.',
#   "I've got to cover a bet there on the way over. Anyway, it gives us a chance to talk.",
#   'Nothing ever stops you from talking, Charley.',
#   'The grapevine says you picked up a subpoena.',
#   "That's right... .",
#   'Of course, the boys know you too well to mark you down for a cheese-eater.',
#   'Mmhmm.',
#   'You know, the boys are getting rather interested in your future.',
#   'Mmhmmm.',
#   "They feel you've been sort of left out of things, Terry. They think it's time you had a few little things going for you on the docks.",
#   "A steady job and a few bucks extra, that's all I wanted.",
#   "Sure, that's all right when you're a kid, but you'll be pushing thirty pretty soon, slugger. It's time you got some ambition.",
#   "I always figured I'd live longer without it.",
#   'Maybe.',
#   "There's a slot for a boss loader on the new pier we're opening up.",
#   'Boss loader!',
#   "Ten cents a hundred pounds on everything that moves in and out. And you don't have to lift a finger. It'll be three-four hundred a week just for openers.",
#   "And for all that dough I don't do nothin'?",
#   "Absolutely nothing. You do nothing and you say nothing. You understand, don't you, kid?",
#   "Yeah yeah I guess I do but there's a lot more to this whole thing than I thought, Charley.",
#   "You don't mean you're thinking of testifying against ",
#   "I don't know I don't know! I tell you I ain't made up my mind yet. That's what I wanted to talk to you about.",
#   "Listen, Terry, these piers we handle through the locals you know what they're worth to us?",
#   'I know. I know.',
#   "Well, then, you know Cousin Johnny isn't going to jeopardize a setup like that for one rubber-lipped",
#   "Don't say that!",
#   "ex-tanker who's walking on his heels ?",
#   "Don't say that!",
#   'What the hell!!!',
#   'I could have been better!',
#   "The point is there isn't much time, kid.",
#   "I tell you, Charley, I haven't made up my mind!",
#   'Make up your mind, kid, I beg you, before we get to four thirty-seven River... .',
#   "Four thirty-seven that isn't where Gerry G...?"],
#  283998: ['Spock.',
#   'The emergency channel, open.',
#   'To anyone within the sound of my voice: This is Captain James T. Kirk of the Federation Starship Enterprise. If you read me, acknowledge. Acknowledge.'],
#  284041: ["Wait!  You know we'll never make it through the Great Barrier.",
#   'But if we do, will that convince you that my vision was true?',
#   'Your vision?',
#   'Given to me by God.  He waits for us on the other side.',
#   'You are mad!',
#   "Am I? We'll see."],
#  65593: ['Hello?',
#   "It's Elvis...",
#   'Who?',
#   "It's me...",
#   'Marcel?',
#   'Yes. We went to the address we were given and had to tie up the owner of the house who turns out to be some Mafia guy.',
#   "You're there now?",
#   'Oui.',
#   "You're calling me on your cell phone, right?",
#   'No.',
#   "You're calling me on is phone?",
#   'Oui.',
#   "My number's going to show up on his bill!",
#   'Should I call you back?',
#   "You've already robbed the safe?",
#   'Oui.',
#   "Take what you've got and get out of there."],
#  280724: ['I got you covered.', "That's reassuring."],
#  60: ['Why do girls like that always like guys like that?',
#   "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#   'He always have that shit-eating grin?',
#   "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#   'You know French?',
#   "Sure do ... my Mom's from Canada",
#   'Guess who just signed up for a tutor?',
#   "You mean I'd get a chance to talk to her?",
#   'You could consecrate with her, my friend.',
#   "The vintage look is over, Kat. Haven't you been reading your Sassy?",
#   'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#   "They're running the rest of me next month.",
#   'The people at this school are so incredibly foul.',
#   "You could always go with me.  I'm sure William has some friends."],
#  65597: ["You think it's smart to tell him we're French?",
#   "I think he's already figured that out.",
#   'We are being watched. Daniel grabs the binoculars and looks.',
#   'Cops?'],
#  63: ['Yeah, just a minor encounter with the shrew.',
#   "That's her?  Bianca's sister?",
#   'The mewling, rampalian wretch herself.'],
#  65600: ['What do we do?',
#   'I was told to take what we have and go.',
#   'Go where?   The police are outside.'],
#  65: ['In the microwave.', 'Make anyone cry today?'],
#  65602: ["I don't know.     Maybe if we did just leave --",
#   "C'mon, get real, will you. You think he's just going to forget about this? These guys are all about respect. All about honor. He's coming after us, so we might as well take the money."],
#  67: ["Where've you been?", 'Nowhere... Hi, Daddy.'],
#  72: ["What's a synonym for throbbing?",
#   'Sarah Lawrence is on the other side of the country.',
#   'I know.',
#   'I thought we decided you were going to school here.  At U of 0.',
#   'You decided.'],
#  262218: ["There's one thing I don't understand.  The thing I don't understand ... is every motherfucking thing you're saying.",
#   "Look, mush, you're the guv'nor here, I can see that, I'm on your manor now, right.  So there's no need to get out of your pram.  I'm Johnny-come-lately to all this.  Whatever the bollocks between you and this slag Valentine, it's got nothing to do with me.  I don't wanna know.",
#   "Well, I'll tell you.  I believe this Valentine screwed me out of a fair sum of money.",
#   "I can well believe it.  I'm sure he has done, son.  He's about as straight as a dog's hind leg.",
#   "But I can't be sure.  I don't even know who he is.  He's too insulated.  Too many layers around him.",
#   "Your guess is as good as mine, mate.  I'm here on another matter entirely.",
#   'Yeah, I guess you are.',
#   "Good job your lot showed up when they did or it would've been <u>me</u> for the high jump.",
#   "That dude who works for Valentine.  He's the one sent those guys after you.  You know that.",
#   "Yeah.  Shouldn't wonder.  Must've done.",
#   "So what's your beef, pal?",
#   "Nothing financial.  Strictly personal.  I can see how all this import-export malarkey might give rise to confusion where I'm concerned.  A foreigner, showing up unexpectedly, like.",
#   'It was you.  Downtown.',
#   'Eh?',
#   "Because that wasn't anything to do with me.  And suspicion has been cast in my direction.  Didn't make any sense.  Choosing those shitheads over me, cutting me out of the deal, then screwing them over too.",
#   'No, I can reassure you on that point. Valentine was just as surprised by that turn of events as you.',
#   "He'd already grabbed more than his allotted cut.  Didn't think he'd be so bold as to take all of it.",
#   'All of what?',
#   'Of the deal, man.',
#   'Oh, yeah, right.  The deal.',
#   "But if you're mad at him too and he's mad at you ... that must make us pals.",
#   'As you prefer, squire.  As you prefer.',
#   "In which case I'll just do what I usually do.",
#   'And that is?',
#   'What am I doing?'],
#  65612: ["How'd it go? I don't know.     Daniel, how would you say it went?",
#   "I would have to say... pretty fuckin' bad. You gave us the wrong address Sophie.",
#   "No, I didn't.",
#   'Bastaldi got the address from you, yes?',
#   'Yes.',
#   'And he gave it to us.    145 Ridgeway Road.',
#   'No.    145 Ridgeroad Way.',
#   'That moron.',
#   'It was an honest mistake. Ridgeway... Ridgeroad... Ridgeway Road.',
#   "Everyone get some sleep.    We're leaving in the morning."],
#  303119: ['Hiya, pardner.  Long time no see.',
#   'Did anybody follow you?  See you come here?'],
#  79: ["Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#   "No! You're not dating until your sister starts dating.  End of discussion.",
#   'What if she never starts dating?',
#   "Then neither will you.  And I'll get to sleep at night.",
#   "But it's not fair -- she's a mutant, Daddy!",
#   'This from someone whose diary is devoted to favorite grooming tips?',
#   'Enough!'],
#  65616: ["-- you stole my cousin Enrique's car.",
#   "Hector, don't interrupt me.",
#   "He told Enrique he didn't know anything about his car.",
#   "I don't give a shit about your cousin's car. We're here about my car. So, shut your mouth! You think you can do that? You think you can keep your big mouth shut?"],
#  262226: ['Straight rotation, no shit, call your shot.',
#   'Lemme break.',
#   'You broke last time.',
#   'Let him break - he likes to break.',
#   'Fuck you.',
#   "I wouldn't talk.",
#   'Huh?',
#   "I saw your mother on the Strip last night.  She went up to three guys, said she'd like 'em to stick one in each, know what I mean?"],
#  196691: ['I had to, Edie. I had to see you.',
#   "Lucky Pop isn't home, he'd kill you.",
#   "You think I stink, don't you? You think I stink for what I told you?",
#   "I don't want to talk about it. I want you to go.",
#   'Edie, listen to me! I want you to believe me. I want to be with you.',
#   "How can you be with Charley and Johnny Friendly and still be with me? Either way it's a lie. It's like there were two different people inside of you. You've got to be one or the other.",
#   "I don't want to hurt Charley I don't want to hurt you...",
#   "It's you who's being hurt. By keeping it inside you, like a poison. Sooner or later it's got to come out.",
#   'I know what you want me to do!',
#   "I don't want you to do anything. Let your conscience tell you what to do.",
#   'That  word again! Why do you keep saying conscience, conscience... .',
#   'I never mentioned the word before. In his agony he grips a glass standing on the night table.',
#   "I keep hearing it and I don't know what to do..I don't know what to do... .",
#   'My hand.',
#   "It's just a scratch. You won't die. She turns away from him.",
#   'Edie...',
#   'Get away from me.',
#   'Edie, I need you to love me. Tell me you love me.',
#   "I didn't say I didn't love you. I said stay away from me.",
#   'Edie, Edie, I...'],
#  78564: ['What do you want?',
#   'Oh.  Hi, Tammy.  I was just, you know, I went to all your teachers and got your assignments.',
#   'I just thought, well, last time you got suspended you fell so behind and -',
#   'Okay, Paul.  Thanks.  Thanks a lot.',
#   'Now could you leave me alone?',
#   "Yeah.  Oh, one more thing. Tammy. You know, all this election stuff. 'Cause, you know, everyone is saying it's so weird that you're running against me, and, well, it is kind of weird, and you haven't really told me why you're doing it and didn't tell me in advance or anything.  But that's okay, you know.  l respect your privacy.  I just want you to know that no matter who wins, if it's you or me, there's no hard feelings. We're still brother and sister.  Okay? Cause... and I hope you feel the same.",
#   'Sure, Paul.  No hard feelings.',
#   'Okay.  Great.  I feel good.'],
#  109241: ["It's good to see ya, man. You changed your look -", 'You, too'],
#  278455: ['One purse--  empty. One vanity case-- ',
#   "But really, m'sieu, this isn't necessary.",
#   'Please, Madame Colet, I believe in doing things correctly. Shall we continue?  Two hairpins, one cigarette lighter, one box of real matches, and-- Oh, yes, this letter from Major--',
#   "Oh! You didn't read it!",
#   'Naturally I did.',
#   'Oh!',
#   "You needn't be embarrassed, madame. A lady as charming as you would, and <u>should</u>, get love letters.",
#   "M'sieu Laval!",
#   "But one suggestion, madame.  Not the major.  I don't  mind his grammatical mistakes. I'll overlook his bad punctuation. But the letter has no mystery--no bouquet--no ...  And one lipstick ...  Scarlet number four.",
#   "What's wrong now?",
#   'With your skin, I prefer crimson.',
#   'Too much blue in crimson.',
#   "That's what you need!",
#   'No, no, no!  I disagree with you completely! I tried it once--',
#   'What shade of powder do you use?',
#   'Peaches and cream.',
#   "That's too dark.",
#   'Do you realize I have light eyes?',
#   "But, Madame Colet, that's a matter of eye shadow. I can straighten that out in two seconds."],
#  196700: ['Charley.',
#   "I mean it, let's get away from here, first Joey then Nolan, now Charley and any minute... .  ...I'm frightened I'm frightened.",
#   "I'll take it out of their skulls.",
#   "I don't want to see you killed. I want to live with you. Live with you. Any place it's safe to walk the streets without... .",
#   "I'll take it out of their skulls.",
#   'Terry, no, no... .',
#   "Don't hang on to me. And don't follow me. Don't follow me.  Call the Father. Ask him to take care of Charley for me. My brother. There's something I got to do."],
#  240314: ["Look.  We're talking about life and death here.  I don't know why we're even having this conversation.",
#   "Well what would you know about it? You don't have anything to lose.",
#   "You're gonna give him those bank codes, you know why?  Because I'm telling you to, that's why.  I'm not losing my life over some greedy pig.",
#   'Who are you calling a pig, rummy?'],
#  65632: ['They were all French guys.',
#   'French guys?    You mean like from France?',
#   'Yeah, French guys from France.',
#   "What'd they take?",
#   'Everything.',
#   'Everything?',
#   'Everything.',
#   'Boy, you must be pissed.',
#   'Well, you know, when five guys break into my house in the middle of the night, stick guns in my face, tie me up and steal from me... it does irritate me.',
#   "Well, I must say you're handling it very well.",
#   "You know why I'm handling it very well? Because you're going to get these guys for me.",
#   'Okay boss.   Where are they?',
#   "If I knew where they were you wouldn't have to find them, would you?",
#   'You didn\'t say find them. You said, "get them."',
#   'Just find them!',
#   'Okay boss.'],
#  196705: ["Terry, you're bleeding.",
#   'Do what I told you. Take care of Charley.',
#   "Terry, for God's sake.",
#   'Get out of my way.',
#   "No, I can't let you. I can't, you're"],
#  99: ["But she doesn't want to date.",
#   'Exactly my point',
#   'Jesus!  Can a man even grab a sandwich before you women start dilating?',
#   'Tumescent!',
#   "You're not helping.",
#   'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#   "Well, I thought we'd start with pronunciation, if that's okay with you.",
#   'Not the hacking and gagging and spitting part.  Please.',
#   "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#   "You're asking me out.  That's so cute. What's your name again?",
#   'Forget it.',
#   "No, no, it's my fault -- we didn't have a proper introduction ---",
#   'Cameron.',
#   "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#   'Seems like she could get a date easy enough...',
#   'Why?',
#   'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#   "That's a shame.",
#   'Gosh, if only we could find Kat a boyfriend...',
#   'Let me see what I can do.'],
#  278259: ['Drop it.', 'Take him!'],
#  103: ['I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#   "Unlikely, but even so, she still can't go out with you.  So what's the point?",
#   'What about him?',
#   'You wanna go out with him?'],
#  65640: ["Can't sleep?",
#   'No.',
#   "I'm sorry things went so wrong today.",
#   "It's not your fault.",
#   'What are you doing?',
#   "I thought I'd listen to some of the tapes. See what's so important that a mob guy has to lock it away in his safe.",
#   'Sounds boring.',
#   "It's three in the morning.    Not much else to do."],
#  273084: ["I can't imagine a fate worse than being dumb. Turn around.",
#   'To be deaf?',
#   'Oh yes, dear too - TERRIBLE! AWFUL!"\''],
#  65642: ["Oh, man... this is bullshit!    You can't trust anyone these days.",
#   "She took everything!    Didn't even leave us cab fare."],
#  196716: ['Is Johnny in?',
#   'No.',
#   'No?',
#   'Give me a double.',
#   'Take it easy now, Terry.',
#   'Keep the advice. Give me the whiskey.',
#   "What's wrong with your shoulder?",
#   'Hit me again.',
#   "Listen, kid, why don't you go home before Johnny... .",
#   'No advice. Just whiskey.',
#   'Easy. Easy, boy.'],
#  65645: ["What's the big deal? It's not like I was on guard duty or something.",
#   "You didn't think it was little suspicious that someone you only knew for a few hours wanted to sleep with you?",
#   'No.   Chicks dig me.'],
#  65647: ['Holy shit.', 'What?'],
#  114: ["What makes you think he'll do it?",
#   'He seems like he thrives on danger',
#   "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#   'They always let felons sit in on Honors Biology?',
#   "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#   "Forget his reputation.  Do you think we've got a plan or not?",
#   "Did she actually say she'd go out with you?",
#   "That's what I just said",
#   "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#   'I thought you hated those people.',
#   "Hey -- I've gotta have a few clients when I get to Wall Street."],
#  262163: ["Maybe she doesn't even know the English guy.",
#   'Avery said she was tight with his daughter.',
#   "That don't mean nothin'.",
#   "She's nice lookin'.",
#   'So what.',
#   "I dunno.  I just said she's nice lookin'.",
#   "And I said so what.  You think she's any happier?",
#   "What d'you mean, any happier?",
#   'Any happier than any other asshole in life.'],
#  65653: ["No wonder Zammito didn't want us to walk out with this stuff. He's planning on killing Bonanno and taking over the family.",
#   "This wasn't the deal! The deal was to steal a necklace, not get in the middle of a Mafia war.",
#   'The deal is whatever Mr. Bastaldi says it is.',
#   "You know, if you could get your nose out of Bastaldi's ass for two seconds you might see what's going on around you.",
#   'I knew this was a mistake! I knew it last night when you asked me to go along with this. I could hear that little voice in my head saying, "don\'t do it! Don\'t you do it!" Jesus, why don\'t I ever listen to myself?',
#   "Yeah, but you did do it.   So let's deal with that."],
#  131190: ['HOW MUCH?!',
#   'My twenty-five per cent. Approximately fifteen hundred bucks.',
#   "Oh, you crumb. With that fifteen hundred I coulda beat him. That's all I needed, Charlie.",
#   'Aw, Eddie.',
#   "C'mon, c'mon, just give me the money.",
#   'What for? To play Fats again?',
#   'Yeah, to play Fats again.',
#   "You wanna come back on the road with me, okay, the money's yours. But if you wanna give it to Minnesota Fats... nothing doing. What do you say?",
#   "You still don't see it, do you, Charlie? You are nothing but a small- time Charlie. You'd love to keep me hustling for you, huh? Wouldn't ya? I mean, a couple more years with me, scuffling around them little towns and those back alleys. You might make yourself enough to get a little poolroom back in Oakland. Six tables and a handbook on the side. Is that when you say goodbye to me, Charlie?",
#   'Is that what you think?',
#   "Yeah, that's what I think.",
#   "All right. That's what I want. Poolroom with a little handbook on the side. Getting old.",
#   "Lay down and die by yourself. Don't take me with you.",
#   'Just like that?',
#   'Yeah. Just like that.'],
#  120: ['Hey.',
#   'Are you lost?',
#   'Nope - just came by to chat',
#   "We don't chat.",
#   "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#   "We're not."],
#  229396: ["I don't know.",
#   'Now think real hard, Doc.  Think.',
#   'Maybe he showed me something.',
#   'Try to think what it was.'],
#  196730: ['You ought to go home and take care of that',
#   'First things first.',
#   'I want to see you, Terry.',
#   "You got eyes. I'm right in front of you.",
#   "Now don't give me a hard time.",
#   'What do you want from me, Father.',
#   'Your gun.',
#   'Mind your own business, Father.',
#   'This is my business.',
#   "Why don't you go and chase yourself?",
#   'Give me that gun.',
#   'You go to hell.',
#   'What did you say?',
#   'You go to'],
#  123: ["But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#   'Does this conversation have a purpose?',
#   "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job."],
#  196732: ['Take your hands off me. What you call me?',
#   "A bum. Look what you're doing. You want to be brave? Firing lead into another man's flesh isn't brave. Any bum who picks up a .45 in a pawn shop can be that brave. You want to hurt Johnny Friendly? You want to fix him for what he did to Charley and a dozen men who were better than Charley? Don't fight him like a hoodlum down here in the jungle. That's just what he wants. He'll hit you in the head and plead self-defense. Fight him tomorrow in the courtroom with the truth as you know it  Truth is the gun Drop that thing and tell the truth a more dangerous weapon than this little   cap pistol."],
#  125: ['You got him involved?',
#   "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca."],
#  131198: ['What are you writing?',
#   "Oh, it's a story. A story I'm making up.",
#   'Give it to me.',
#   "What's this supposed to mean?",
#   'Give it back to me.',
#   'What\'s this supposed to mean: "We have a contract of depravity. All we have to do is pull the blinds down."'],
#  65665: ["Tell me the truth Hector... do you think we'll find my car?",
#   'Hard to say.',
#   "How do we know what room she's in?",
#   'Wait here.'],
#  131203: ['Give me a bottle of beer.', 'Right.'],
#  133: ['So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#   'William would never have gone to a state school.',
#   "William didn't even go to high school",
#   "That's never been proven",
#   'Neither has his heterosexuality.',
#   "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#   'Does it matter?',
#   'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."'],
#  136: ["I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#   'Touch of the flu.',
#   "I'm at a loss, then.  What should we talk about? Your year of absence?"],
#  65673: ["I really thought we had something special going. I can't tell you what a disappointment you've turned out to be.",
#   'After last night I could say the same for you.',
#   "The money isn't here.",
#   'Where is it, Sophie?',
#   "I don't know.",
#   "If you think because you're a women this can't go hard on you, think again.",
#   'Who are you waiting for?',
#   'Stick around and find out.'],
#  229573: ['No.',
#   'He is, Mr. Torrance.',
#   'Who?',
#   'A nigger.',
#   'A nigger!',
#   'A nigger cook.',
#   'How?',
#   "Your son has a very great talent. I don't think you are aware how great it is, but he is attempting to use that very talent against your will.",
#   'Well, he is a very willful boy.'],
#  140: ["Why don't we discuss your driving need to be a hemorrhoid?",
#   "What's to discuss?",
#   "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#   "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good..."],
#  273090: ['T-w~e-l-v~e.',
#   'Te, kawnarna paraikete mo te tahi hawlie 0 te whenna uci.  UNSUBTITLED'],
#  188092: ['Come with us, sir.', "I'd like to know what..."],
#  196752: ['Jimmy...',
#   "He's going to have to grow up too.",
#   'My pigeons... .',
#   "Terry, you better stay in for a while. I'll come and cook your meals. Be sure you keep the door locked.",
#   "Every one of 'em... .",
#   "You heard what Johnny said. No part of the Waterfront'll be safe for you now. Maybe inland the Middle West somewhere a job on a farm... .",
#   'Farm...'],
#  196754: ["Then go ahead go ahead! Go down to the shape-up and get yourself killed, you stupid, pigheaded, son of a  What are you trying to prove? With a decisive gesture Terry takes the hook and sticks it through his belt. Then he goes to the wall and lifts Joey's windbreaker from the nail on which it has been hanging. He puts the windbreaker on in a deliberate way, and grins at her as he does so; then he walks to the door with a sense of dignity he has never had before.",
#   "You always said I was a bum. Well  not anymore. I'm going down to the dock. Don't worry, I'm not going to shoot anybody. I'm just going to get my rights.  Joey's jacket. It's time I start wearing it."],
#  147: ["C'esc ma tete. This is my head",
#   "Right.  See?  You're ready for the quiz.",
#   "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#   "That's because it's such a nice one.",
#   'Forget French.',
#   'How is our little Find the Wench A Date plan progressing?',
#   "Well, there's someone I think might be --"],
#  149: ['There.', 'Where?'],
#  178595: ['Yes--right here. Just a second--  Miss Paine.',
#   "*Who*! Miss--! Is that--? Why didn't you--? Holy smoke;  H-hello... Yes, Miss Paine... How-- how are you, Miss Paine...? What?... Escort *you* Gee--I mean--*sure*-- *yes*! I'd be--. Reception for a *princess*! Gosh!... Thanks, Miss Paine. Yes. I--I'll be there! Goodbye, Miss Paine.  Did you hear that?--Escort Susan Paine--reception for a princess! Imagine her calling me--asking *me*-- !",
#   "Get your hat, Senator. We've got a lot to do between now and tomorrow--",
#   'Wow!',
#   "I--I'm awfully glad to be--that is, it was nice of you to--  Uh--how's your father?",
#   'Splendid.',
#   "Uh--that's good. And--uh--you?",
#   "I'm splendid, too.",
#   "That's--that's splendid.",
#   "And how's your bill, Senator?",
#   "Oh, the bill. Oh--splendid--I mean--  I--I just can't seem to talk in this suit.  I'll tell you a secret. It's brand new.",
#   "Well! You don't say!",
#   "It's just as well to tell you--because if we're going to get off on the right foot--I mean--in case I act sort of strange--it's the suit.",
#   'Well--I--',
#   'Funnier things have happened. Ma says when Pa was courting her, he acted strange for months. Didn\'t make sense--or anything. And one day, on a hunch, Ma said: "Clayton, so help me, you talk like a man whose collar is too tight to bear." "Not the collar, Mary," he said, "my shoes." "Well, for land\'s sake," Ma said, "Take the pesky things off!" Which Pa did, an\' they were engaged within a week.',
#   "You're not going to take your *suit* off!",
#   "No! No! Gosh. See, there you are! I'm not making sense!",
#   "Well--I stuck my foot in it again at the President's press conference today--  How come so early? Get the day off?",
#   'They decoyed the little General off to a tea party to keep him out of the Senate.',
#   'Well, well--  Yeah--I got smart and thought I\'d slip one over on the old man in the press meeting. I said, "Mr. President, about the monopoly investigation--" And he jumps right in and says, "Diz, if you were sitting in my chair, would you answer the question you\'re about to ask?" He had me.',
#   "I don't mind *who* gets licked in a *fair* fight, Diz. It's these clouts below the belt I can't take. Sicking that horrible dame on him--when he's goofy about her--",
#   'What dame?',
#   'Paine.',
#   'Oh--yeah--',
#   'He isn\'t going to hurt enough as it is. *She* has to twist a knife in him, too--the regal jackass! "I\'ll turn my glamour on him," she says--',
#   "Forget it, kid. What's it *to* you?",
#   "Nothing. I'm just saying--I might be able to lie, cheat, steal--and I'd still tear into a guy I saw kicking a dog. Not that *he* is, by a long shot--",
#   "Okay. So what? Stop worrying. I've told you--the dopes are gonna inherit the earth anyway--",
#   "I've wondered, Diz--maybe this Don Quixote's got the jump on all of us. I've wondered--maybe it's a curse to go through life wised up like you and me--",
#   "Now, look, kid--if we're gonna wonder, let's go down and do it over a hunk of steak.  Come on, snap out of it. Diz Moore-- that rarest of companions--is here at your side.  To genteel crime, kid.",
#   'And to Don Quixote!'],
#  65687: ['Why?',
#   'Vincent Bastaldi is in jail.',
#   'For what?',
#   'Laurant and Vincent were in business with Zammito.',
#   'What kind of business?',
#   "Black market art. Zammito got to a few key security guards at the Metropolitan Museum. The Bastaldi's supplied the artists to make copies of famous works. They'd switch the paintings, send the originals to Paris and the Bastaldi's would sell them to private collectors.",
#   'We\'re talking Matisse, Renoir, Monet. We know for sure they replaced Van Gogh\'s "Vase with twelve sunflowers" last week with a copy. It was on loan from the London National Gallery and they\'re not going to be very happy when they find out about it.',
#   'So Bastaldi makes a deal with the Feds to trade up for his brother?',
#   "Yeah. He delivers the goods on Zammito. If we got what we wanted we'd let his brother go providing he tells us where the Van Gogh and the other paintings are.",
#   'No one has mentioned the part of the plan about us getting caught and going to prison.',
#   "We're leaving. Raymond get the bag."],
#  218231: ['All he wanted was some mu-shu.', 'Are you okay, Lee?'],
#  269290: ['Outside.',
#   'Sure.',
#   "Clemenza.  You take care of Paulie. I don't ever want to see him again. Understood?",
#   'Understood.',
#   "Okay, now you can move your men into the Mall, replace Tessio's people.  Mike, tomorrow you take a couple of Clemenza's people and go to Luca's apartment and wait for him to show.  That crazy bastard might be going after Sollozzo right now if he's heard the news.",
#   "Maybe Mike shouldn't get mixed up in this so directly.  You know the old man doesn't want that.",
#   'OK forget it, just stay on the phone.'],
#  157: ['Yeah',
#   'What do you think?',
#   'Two legs, nice rack...',
#   'Yeah, whatever.  I want you to go out with her.',
#   "Sure, Sparky.  I'll get right on it.",
#   'You just said',
#   'You need money to take a girl out',
#   "But you'd go out with her if you had the cake?"],
#  198270: ['Somebody called you?',
#   'Can we come in?',
#   'What do you want?',
#   "We'd like to come in.",
#   "No, you can't come in."],
#  65697: ["Zero.   That's all I know.",
#   "You'll never get out of the city.",
#   "Bastaldi's dead. He is fuckin' dead!",
#   'You want Zero to kill him?',
#   "I'm going to kill him myself!",
#   'What about the money?',
#   "It has to be at Sophie's. She didn't have time to go anywhere else before she came here.",
#   "We don't know that for sure.",
#   "Forget the money! We've got bigger problems than the money right now.",
#   'She probably hid it at her place.    The six of us could find it in --'],
#  196771: ['Terry...?', 'Terry... Terry... .'],
#  165: ['You got it, Verona.  I pick up the tab, you do the honors.',
#   "You're gonna pay me to take out some girl?",
#   "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#   'How much?',
#   "I can't take a girl like that out on twenty bucks.",
#   'Fine, thirty.',
#   "Take it or leave it.  This isn't a negotiation.",
#   "Fifty, and you've got your man."],
#  196775: ["They're waiting for him to walk in.",
#   'You hear that, Terry?  Terry, did you hear that?  You lost the battle but you have a chance to win the war. All you gotta do is walk.',
#   '...walk?',
#   "Johnny Friendly is layin' odds that you won't get up."],
#  169: ["I mean Wo-man.  How ya doin'?",
#   'Sweating like a pig, actually.  And yourself?',
#   "There's a way to get a guy's attention.",
#   'My mission in life.'],
#  65706: ["This is turning to shit. If word gets out of my involvement in this I'll go to prison.",
#   "Listen, we know their names. They don't know the city. You'll find them. You're the FBI.",
#   "I can't bring the Bureau into this.    If I do the tapes become evidence.",
#   "They're supposed to be evidence.    That's why Bastaldi set this up.",
#   'Fuck Bastaldi and his brother. These tapes are gold. Do you have any idea what Zammito would pay to get them back?',
#   'I thought you wanted Zammito?',
#   "What for? The minute I get him some other Gavone will take his place. I've been doing this for twenty years. When I retire it's not going to be to some trailer park in the suburbs.",
#   'Too many people know about my involvement in this.',
#   "Then we just have to make sure everyone who knows can't say anything."],
#  196779: ['You can!', 'I can? Okay.  Okay...'],
#  262316: ["Hey, Elaine.  You even know what he's saying half the time?",
#   'No, but I know what he means.'],
#  174: ['Pick you up Friday, then',
#   'Oh, right.  Friday.',
#   "The night I take you to places you've never been before.  And back.",
#   'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
# ...
#   "Jim, maybe we should just go. I've got to look in on the kids. Paul is supposed to be coming back in from the city.",
#   'Jesus, let me make it up to you -- I can do better than that, honestly --',
#   'Well, we can talk about it.',
#   "That's fine. I wouldn't expect you to see it any other way.",
#   "Maybe you just need -- look, can you wait here a sec, I need to tidy up -- just a minute, I'll be right back. You'll wait?",
#   'Of course.',
#   'Elena.',
#   "Ben, I've got a ride home. Maybe you should sleep this one off on the couch here?",
#   "I'll drive you --",
#   'Ben.'],
#  269735: ["I wasn't too over the top?",
#   'No, it was the perfect level.',
#   'Thanks. Oh, did I tell you. I picked up that new KC and the Sunshine Band record that you recommended. You were right, it is good.'],
#  208188: ['This is Barry.',
#   "Hey it's me, what are you doing?",
#   "Hello, Karen. I'm just working.",
#   'Yeah but what are you doing?',
#   "I'm just working....I have some customers here.....",
#   "So you can't talk to me?",
#   "I have a few people here, I can't really chat right now.",
#   '"chat?" Did you just say "chat?"',
#   "Well, I can't talk though --",
#   'You just fucking said "chat," that is so -- what are you now? "chat." I\'m just calling to make sure you show up at this party tonight.',
#   "Yes, I'll be there.",
#   'Fine. You get back to chatting with your precious customers.',
#   'Ok, bye-bye.',
#   'Sorry about that.',
#   "I didn't know you had a sister?",
#   ".....Well yes I do....  But one more thing I wanted to tell you guys about the new plungers is that we're making the handles now in a non-breakable material called....."],
#  1443: ["So...who's Nicky?",
#   'What do you want?',
#   'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.',
#   "What's your accomplishment.",
#   'I kill someone famous.',
#   'Then do it, asshole.',
#   'Good - be tough to the end.  Actor who plays you will want to die like hero.',
#   "So tabloids don't have to do re enactments.  They going to have real movie this time.",
#   "If you kill me and film it you're putting a noose around your neck."],
#  66982: ['Do you think this childish machismo impresses me?  When I was a boy in Saigon I watched my country change one block at a time,  one building at a time.  Whole lives erased.  A way of life, polluted.  Today, no one forces me to move.  I use my powers to change your country, one block at a time,  one building at a time.',
#   "Nice speech.  What's it supposed to mean?",
#   'Your comprehension is not required.  Your cooperation and, indeed, your ability are the issues on the table.'],
#  262385: ['OK, boys, which of you gets the privilege?',
#   "We're just closing, friend.",
#   'Oh, happy days! I wish I was doing well enough to turn away business! More power to ya, brother! The public be damned!',
#   "Hey, what's your problem, friend? This is a business establishment with posted hours--"],
#  1449: ["No.  We are insane.  Who else but crazy men would film their murders?  So we kill someone famous and if we are caught, we are sent to mental hospital. But what good is money there?  Because once in hospital I say I not crazy. Just pretended to be acquitted.  We see psychiatrists.  They must certify we are sane and because of your - what is law called?  Oh - I got it.  Because of your Double Jeopardy law, we can't be tried for same crime twice.  We come out free, rich and famous!",
#   'Good idea!',
#   "You really think you'll be able to fool a jury with this bullshit?  How fuckin' stupid are you?",
#   "Smarter than Americans.  You're fed cry baby talk shows all day long.  Not only will Americans believe me, they'll cry for me.  So...Detective Eddie Flemming, would you like to say goodbye to your Nicolette? Maybe you can propose to her now?",
#   'Okay.  He has nothing to say.  Start the camera!',
#   'Cut!'],
#  132525: ['Sandy, you scared the shit out of me.',
#   'What are you doing?',
#   "Just thought I'd stop by.",
#   "Mike's out -- I think he went to Silver Meadow to see if you were hanging around there.",
#   'Yeah.',
#   'Are you his girlfriend?',
#   'No.',
#   'You okay?',
#   'Yeah. You?',
#   'Yes. Well, I guess we can walk from here.'],
#  198062: ["It's still a good plan.  It's just... got a twist.",
#   'Yeah.  Kidnapping.',
#   "Not if we keep 'em here.  You can't kidnap somebody in their own house. It's just breaking and entering, unless we take 'em someplace.  Or something like that, I'm pretty sure.",
#   'Pure idiot.',
#   "I am.  I'm an idiot's son.  An idiot's grandson.  I'm third- generation idiot.  But for once in my life I had a good idea, and I'm not giving up so easy.  You are? Are you actually telling me that for the first time in your life you're gonna throw your cards on the table and go home early?  I can't believe my eyes.  Fourteen million dollars upstairs, Burnham.  You'll be out of the hole. Baby, you'll be so far out of the hole you could draw bricks every night for the next twenty years and still shit green.  Come on, Buddy.  One more hand."],
#  198064: ["What's going on?!", 'People.  In the house.'],
#  1457: ['I know.',
#   'What do you mean you know?  He told you he was gonna propose to me?',
#   'Well, he...',
#   'I want to hear everything he said.',
#   "I'm trying to tell you.",
#   'Alright.  Go ahead.',
#   'That morning.  He was talking to me and Leon about marriage.',
#   'Oh my G-d.  We were having lunch here. He started making overtures - talking about little shoes next to his in his closet but I got a call to anchor - and I walked out on him.  I walked out on him when he was trying to ask me to marry him!!'],
#  132531: ["He's dead.",
#   "If it wasn't raining we could take him outside and blow him up.",
#   "He wouldn't blow up. He'd just get all mangled or twisted.",
#   'Well.  It looks like someone got to his private parts before us.',
#   'Communist Viet Cong.',
#   'They left it in the jungle.'],
#  198068: ["He's going down.", 'That room!', 'What?!', 'PANIC ROOM!'],
#  132533: ["We -- we have to go to the guest room. We can't stay in here. What if Mikey? My parents?",
#   "Don't worry about them. They're at that party, getting drunk and falling all over each other and making jokes about McGovern and stuff."],
#  1462: ['Robert...?',
#   'What are you doing here?',
#   "You've got a call.",
#   "I can't talk to anybody right now, can't you see I'm busy!  I can't talk business.  Hang up.  Have a drink.  Get her a whiskey.",
#   "Trust me, you'll want to take this call."],
#  198071: ['Damn it!',
#   "It doesn't work?!",
#   'Different phone line, I never hooked it up!'],
#  132536: ['Want a drink?', 'Vodka?', 'You never tasted the stuff?'],
#  263610: ["Of course, there hasn't been anything to compare with this - the first time an intruder has been a former cast member--",
#   '--a dead one at that.',
#   '--and certainly the first time that an intruder has been rewarded with a starring role.  I really must congratulate you on writing Kirk back in.  A master stroke.',
#   "Since Kirk started this whole crisis in Truman's life, I came to the conclusion that he was the only one who could end it.",
#   "I understand he's hardly had a life of his own since he left the show.  How did you convince him--was it the opportunity to be close to Truman again?",
#   'That and a fat, new contract.',
#   'How <i>do</i> you intend to explain his twenty- two year absence?',
#   'Amnesia.',
#   'Of course.',
#   'Let\'s talk ratings.  "Truman" has always enjoyed top ten status but the huge surge over the last few days--how do you hope to sustain that audience now that Truman appears to have reconciled himself?',
#   "As you know ratings have never been our primary goal.  I imagine we'll lose those voyeurs only interested in witnessing Truman's latest torment.  However, I'm certain that our core audience will remain loyal.",
#   'But recent events have been so dramatic, it does raise the perennial question. What keeps us watching this one man twenty-four hours a day - eating, sleeping, working, sitting for hours in contemplation?',
#   'It has to be the reality.',
#   "We've become tired of watching actors give us phony emotions, bored with pyrotechnics and special effects.  While the world he inhabits is counterfeit, there's nothing fake about Truman himself.  No scripts, no cue cards.  It's not always Shakespeare but it's genuine.  That's how he can support an entire channel.",
#   'A window onto the human condition?',
#   'I prefer to think of it as a mirror.',
#   'Not only does he give us a glimpse of the truth, he gives us a glimpse of ourselves.',
#   'But how do you account for the popularity of those eight hours a day when Truman sleeps?',
#   "We find many viewers leave him on all night for comfort.  Haven't you ever watched your child or your lover sleep?",
#   "Let's go to some of those viewers' calls."],
#  67003: ["I mean, I've done what I came to do.  It shouldn't hurt this much. But it will pass...",
#   "Right.  You sure I can't just take you to the emergency ward?",
#   "They couldn't do anything for me.",
#   "How 'bout the morgue?",
#   'No.  I have one more thing to do.'],
#  132542: ['Have you ever had a nocturnal emission?',
#   'Huh?',
#   "That's the name for when you wake up and find this little pool of sticky stuff, like after a sexy dream."],
#  263615: ['Are we talking Emmies?',
#   'Certainly a nomination.',
#   'Of course, Truman has always been very much in on casting.',
#   "As with our own lives, the only people he can't cast are his family.  Otherwise he has final approval, able to elevate an extra into a lead role as was the case with his only real friend, Marlon, or alternatively relegate a star to a bit player.",
#   "Istanbul, Turkey, you're on with master videographer, Christof."],
#  132546: ['I love you.',
#   "That's nice. Are you drunk?",
#   "I don't know. How do I know?",
#   "I don't know either. You spin around, when you lie down."],
#  132549: ['You want to come in, get a cup of coffee -- warm up? I can either walk you home, or you could crash in the guest room.',
#   'Sure. Maybe coffee.',
#   "Phone's out. I hope the pipe's --"],
#  67014: ['What... the hell is that?',
#   'This is a cobra, Mr. Grange.  Yes, it is real.',
#   'That thing is poisonous.',
#   'Extremely so.  You and I are the recipients of unwanted good fortune, in the form of a man everyone is calling The Crow.',
#   "Give me a break.  That guy's a wacko...",
#   'I intend no slight to you, but I cannot find the English to adequately express just what he is.  I suppose Western mythology would describe him as a Fury.',
#   'Not a Plymouth Fury, I bet.',
#   'Do you know of spirit assassins? You do know the dead can rise? Properly motivated, of course.',
#   'Like some sort of zombie on a revenge trip.',
#   'Mmm.  But tonight I can take what is his.',
#   "Only thing you'll get from that clown is a faster way to die. LAO To the contrary..."],
#  1479: ["Come to 45 Broadway.  Don't bring the Police.  Come alone or you'll be in my next film.",
#   "Look asshole.  I've been threatened by better than you.",
#   "No.  I'm the best that's ever threatened you.",
#   "I'll meet you on one condition - I get exclusivity and you surrender to me.",
#   "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars.",
#   "What?  It doesn't work that way.",
#   "If you don't want my film - I'll call another show.  And they will show it.",
#   'Wait a minute.  Wait a minute.',
#   "Come alone.  Bring cash.  And we'll talk about surrendering.",
#   'How was it?',
#   'Not good.',
#   'Did the D.A. videotape her deposition?',
#   'Yeah.  He finished awhile ago.',
#   'Alright.  Swing by her apartment.  Let her pick up her clothes and take her straight to Hoover Street.  You got that?',
#   'Yeah.',
#   'Chief - mind if I take her?',
#   'Okay.  But not water sports.'],
#  67016: ["Who is only invulnerable so long as he cares about the dead.  When he begins to care about the living, you'll find his heart can bleed... and I want it to bleed for me.",
#   'Kill a dead guy?'],
#  54860: ['Who do you think did it -- Gideon?',
#   'Maybe.',
#   'Or Tex?',
#   'Maybe.',
#   "You're a big help. Can I have one of those?"],
#  67018: ["What's going on...?", 'A remembrance.  A closure.'],
#  132555: ['Do you think? Maybe we should call someone --',
#   "The phone's out.",
#   'Yeah. Well, we can just --',
#   "Ben, I don't think he wants us here."],
#  67021: ["You brought flowers.  As long as you don't forget her, Elly, she lives.",
#   "She's dead.  She's gone.  And now you're just gonna go away and never come back, too.  I hate this place; it isn't fair.",
#   'Elly...'],
#  67023: ['I remember him!  Here, Gabriel... here kitty... Gabriel... Is he still yours?',
#   "I think he's yours, now."],
#  1489: ['Is he your boyfriend?',
#   "Ludwig?  He's gay - are you jealous?",
#   'If I was your boyfriend, I might be.',
#   "If you were my boyfriend, I'd suggest you find another girlfriend that isn't going to jail ten-thousand miles away.",
#   'A good Immigration lawyer could stall the process.  Eddie recommended one.',
#   "No matter what happens...I'm glad I met you.",
#   "I'm glad I met you."],
#  263634: ["You've never actually met Truman, yourself.  Never thought about doing a cameo--playing a veterinarian, or a priest, something like that?",
#   "I've been tempted.  But I think it's important to retain objectivity.  I wouldn't want to get emotionally caught up.",
#   'The Hague for Christof...The Hague?...lost them.  Hollywood, California, you\'re on "Tru Talk."'],
#  67028: ["I was wonderin' where you'd gotten to --  Oh, Elly, honey, a cat.  Here?",
#   "He was a present.  Besides, we're moving anyway.  You said.",
#   "We'll discuss this later. Obviously.  You left the door open."],
#  132565: ['A meteor?',
#   'No Sir. Definitely not.',
#   'How do you know?',
#   "Well, er... it's slowing down.",
#   "It's doing what?",
#   "It's... slowing down, Sir."],
#  263638: ["--What are my plans now?  Well, next I'm thinking of tackling the Yuba River in an authentic canoe from the Algonquin tribe. --I'm talking about the north fork, a class five rapid - only I'm not going <i>down</i> the Yuba, I'm going <i>up.</i>  Do you honestly think for one minute I'd go back to some dreary office to rubber stamp meaningless documents...do you?",
#   "--Truman, you're gonna be late!"],
#  1495: ['You better get packed.',
#   'Right.',
#   'Do you have coffee?',
#   'In the kitchen.',
#   "I'll make some for us.",
#   "I'll get my clothes."],
#  132568: ["What are you waiting? My social security will expire, you'll still be sitting there.",
#   "I'm thinking.",
#   'So think already.'],
#  1497: ['What are you doing?', 'Pouring it out!'],
#  263643: ['Why is he in the basement?',
#   'He moved down there after Meryl packed up and left.',
#   "Why wasn't I told?  Any unpredictable behavior has to be reported.  Is that the best shot we can get?",
#   "What's to see?",
#   "What's on the ClockCam?"],
#  1500: ['Get outta here!',
#   'What the hell happened?',
#   'They were inside.  They booby trapped her apartment!'],
#  263645: ['What happened down there?',
#   'He was tidying up his garbage.  I was going to call you.  But half-way through, he gave up and fell asleep.'],
#  1502: ['Viewer discretion advised!', 'You want the tape?  There it is!'],
#  132575: ['You have any idea how long it takes for those things to decompose?',
#   "You don't move soon. I'll begin to decompose.",
#   "David, I've been meaning to talk with you. It's nice you've been spending so much time with me, but...",
#   "Dad, don't start.",
#   "I'm only saying, it's been what? Four years, you still haven't signed your divorce papers.",
#   'Three years.',
#   "Three, four. Move on. It's not healthy."],
#  1504: ['You are success story?  I am success story!  Why do you say I and not we?',
#   "Oleg, don't be paranoid.  You got a hundred-fifty thousand dollars, didn't you?  I gave you half of what they gave me.  Look - here we are!"],
#  ...}

# %%
context_and_target = []
for conves in conves_dict.values():
    # ペアがない会話は捨てる
    if len(conves) % 2 != 0:
        conves = conves[:-1]
    for i in range(0, len(conves), 2):
        context_and_target.append((conves[i], conves[i+1]))

# %%
# ペア完成
context_and_target[:5]
# Out:
# [("Drink up, Charley. We're ahead of you.", "I'm not thirsty."),
#  ("After what we been hearing about your brother, I thought your throat'd be kind of dry.",
#   "So they're walking along and smiling. That doesn't mean he's going to talk. There's no evidence until he gives public testimony."),
#  ("Thanks for the legal advice, Charley. That's what we always kept you around for.  Now how do we keep him from giving this testimony? Isn't that the er as you put it main order of business?",
#   'He was always a good kid. You know that.'),
#  ('Did you change your hair?', 'No.'),
#  ('I believe I have found a faster way.', 'Hmmm?')]

# %%
context, target = zip(*context_and_target)

# %%
context = list(context)
target = list(target)

# %%
context[:5]
# Out:
# ["Drink up, Charley. We're ahead of you.",
#  "After what we been hearing about your brother, I thought your throat'd be kind of dry.",
#  "Thanks for the legal advice, Charley. That's what we always kept you around for.  Now how do we keep him from giving this testimony? Isn't that the er as you put it main order of business?",
#  'Did you change your hair?',
#  'I believe I have found a faster way.']

# %%
target[:10]
# Out:
# ["I'm not thirsty.",
#  "So they're walking along and smiling. That doesn't mean he's going to talk. There's no evidence until he gives public testimony.",
#  'He was always a good kid. You know that.',
#  'No.',
#  'Hmmm?',
#  "Don't expect to get it all, sport, you'll burn out. First rule of business is never get emotional about stock, clouds the judgment. Where do we stand?",
#  "You can have the one next to yours if you want. One twenty.  It ain't took.",
#  "That's got two double beds.",
#  'Good luck.',
#  'Very attractive.  Good idea.  Now I <u>really</u> want to fuck you.']

# %% [markdown]
# ## Step 2. Preprocessing for text data

# %%
# from my_seq2seq_text_cleanear import text_modifier, nonalpha_remover
import re
MAX_LEN = 12

# %%
def clean_text(text):
    '''Clean text by removing unnecessary characters and altering the format of words.'''

    text = text.lower()
    
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    
    return text

# %% [markdown]
# ### 2-1. Clean Text

# %%
tidy_target = []
for conve in target:
    text = clean_text(conve)
    tidy_target.append(text)

# %%
tidy_target[:10]
# Out:
# ['i am not thirsty',
#  "so they are walking along and smiling that does not mean he is going to talk there's no evidence until he gives public testimony",
#  'he was always a good kid you know that',
#  'no',
#  'hmmm',
#  'do not expect to get it all sport you will burn out first rule of business is never get emotional about stock clouds the judgment where do we stand',
#  'you can have the one next to yours if you want one twenty  it ai not took',
#  'that is got two double beds',
#  'good luck',
#  'very attractive  good idea  now i ureallyu want to fuck you']

# %%
tidy_context = []
for conve in context:
    text = clean_text(conve)
    tidy_context.append(text)

# %%
tidy_context[:10]
# Out:
# ['drink up charley we are ahead of you',
#  'after what we been hearing about your brother i thought your throat would be kind of dry',
#  'thanks for the legal advice charley that is what we always kept you around for  now how do we keep him from giving this testimony is not that the er as you put it main order of business',
#  'did you change your hair',
#  'i believe i have found a faster way',
#  'i got all i could get which was 750000 shares plus 5000 march 50 calls average price of $47 a share and $4 per contract for the call i just wish i could have got more',
#  'what about one fortytwo',
#  'no one fortytwo',
#  'ever take a look at the women who work in pet stores  wow',
#  'jesus are you gay enough or what']

# %%
# decoderのinputには<BOS>と<EOS>タグ
bos = "<BOS> "
eos = " <EOS>"
final_target = [bos + conve + eos for conve in tidy_target] 
encoder_inputs = tidy_context
decoder_inputs = final_target

# %%
import codecs
with codecs.open("encoder_inputs.txt", "rb", encoding="utf-8", errors="ignore") as f:
    lines = f.read().split("\n")
    encoder_text = []
    for line in lines:
        data = line.split("\n")[0]
        encoder_text.append(data)

# %%
len(encoder_text)
# Out:
# 143865

# %%
encoder_text[:10]
# Out:
# ['did you change your hair',
#  'i missed you',
#  'it was a bratwurst  i was eating lunch',
#  'you the new guy',
#  "c'mon  i am supposed to give you the tour",
#  'north actually  how would you   ',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'thirtytwo',
#  'how many people go here',
#  'that i am used to']

# %%
with codecs.open("decoder_inputs.txt", "rb", encoding="utf-8", errors="ignore") as f:
    lines = f.read().split("\n")
    decoder_text = []
    for line in lines:
        data = line.split("\n")[0]
        decoder_text.append(data)

# %%
decoder_text[5]
# Out:
# '<BOS> i was kidding people actually live there <EOS>'

# %% [markdown]
# ### 2-2. MAKE VOCABRALY

# %%
full_text = encoder_text + decoder_text

# %%
# 一旦もともと辞書サイズを調べる
dictionary = []
for text in full_text:
    words = text.split()
    for i in range(0, len(words)):
        if words[i] not in dictionary:
            dictionary.append(words[i])

# %%
from keras.preprocessing.text import Tokenizer
VOCAB_SIZE = 14999
tokenizer = Tokenizer(num_words=VOCAB_SIZE)
# Out:
# Using TensorFlow backend.

# %%
# 辞書を作る
tokenizer.fit_on_texts(full_text)
word_index = tokenizer.word_index
len(word_index)
# Out:
# 65283

# %%
# リバースした辞書を用意
index2word = {}
for k, v in word_index.items():
    if v < 15000:
        index2word[v] = k
    if v > 15000:
        continue

# %%
index2word
# Out:
# {1: 'bos',
#  2: 'eos',
#  3: 'you',
#  4: 'i',
#  5: 'the',
#  6: 'to',
#  7: 'is',
#  8: 'a',
#  9: 'not',
#  10: 'it',
#  11: 'that',
#  12: 'do',
#  13: 'and',
#  14: 'are',
#  15: 'of',
#  16: 'in',
#  17: 'have',
#  18: 'what',
#  19: 'me',
#  20: 'we',
#  21: 'he',
#  22: 'am',
#  23: 'this',
#  24: 'for',
#  25: 'will',
#  26: 'know',
#  27: 'was',
#  28: 'your',
#  29: 'my',
#  30: 'on',
#  31: 'be',
#  32: 'no',
#  33: 'with',
#  34: 'but',
#  35: 'they',
#  36: 'would',
#  37: 'just',
#  38: 'all',
#  39: 'like',
#  40: 'did',
#  41: 'about',
#  42: 'get',
#  43: 'so',
#  44: 'out',
#  45: 'if',
#  46: 'here',
#  47: 'she',
#  48: 'him',
#  49: 'up',
#  50: 'how',
#  51: 'got',
#  52: 'can',
#  53: 'want',
#  54: 'think',
#  55: 'at',
#  56: 'there',
#  57: 'one',
#  58: 'right',
#  59: 'go',
#  60: 'now',
#  61: 'well',
#  62: 'going',
#  63: 'her',
#  64: 'why',
#  65: 'see',
#  66: 'as',
#  67: 'oh',
#  68: 'his',
#  69: 'could',
#  70: 'yes',
#  71: 'who',
#  72: 'good',
#  73: 'when',
#  74: 'cannot',
#  75: 'from',
#  76: 'where',
#  77: 'were',
#  78: 'yeah',
#  79: 'tell',
#  80: 'come',
#  81: 'some',
#  82: 'been',
#  83: 'an',
#  84: 'time',
#  85: 'or',
#  86: 'back',
#  87: 'say',
#  88: 'them',
#  89: 'us',
#  90: 'then',
#  91: 'had',
#  92: 'look',
#  93: 'something',
#  94: 'take',
#  95: 'man',
#  96: 'never',
#  97: 'mean',
#  98: 'too',
#  99: 'way',
#  100: 'does',
#  101: 'make',
#  102: 'really',
#  103: 'little',
#  104: 'okay',
#  105: 'more',
#  106: 'down',
#  107: 'sure',
#  108: 'gonna',
#  109: 'any',
#  110: 'should',
#  111: 'thing',
#  112: 'said',
#  113: 'our',
#  114: 'over',
#  115: 'by',
#  116: 'people',
#  117: 'only',
#  118: 'need',
#  119: 'has',
#  120: 'off',
#  121: 'maybe',
#  122: "there's",
#  123: 'very',
#  124: 'mr',
#  125: 'two',
#  126: 'let',
#  127: 'much',
#  128: 'doing',
#  129: 'anything',
#  130: 'give',
#  131: 'nothing',
#  132: 'sorry',
#  133: 'because',
#  134: 'talk',
#  135: 'even',
#  136: 'love',
#  137: 'thought',
#  138: 'into',
#  139: 'ever',
#  140: 'call',
#  141: 'before',
#  142: 'sir',
#  143: 'find',
#  144: 'life',
#  145: 'these',
#  146: 'still',
#  147: 'around',
#  148: 'work',
#  149: 'things',
#  150: 'must',
#  151: 'first',
#  152: 'told',
#  153: 'night',
#  154: 'other',
#  155: 'money',
#  156: 'better',
#  157: 'than',
#  158: 'last',
#  159: 'help',
#  160: 'hey',
#  161: 'long',
#  162: 'those',
#  163: 'always',
#  164: 'believe',
#  165: 'fucking',
#  166: 'put',
#  167: 'please',
#  168: 'guy',
#  169: 'day',
#  170: 'after',
#  171: 'years',
#  172: 'away',
#  173: 'shit',
#  174: 'again',
#  175: 'god',
#  176: "let's",
#  177: 'their',
#  178: 'old',
#  179: 'place',
#  180: 'keep',
#  181: 'great',
#  182: 'feel',
#  183: 'hell',
#  184: 'home',
#  185: 'big',
#  186: 'new',
#  187: 'name',
#  188: 'talking',
#  189: 'kind',
#  190: 'bad',
#  191: 'everything',
#  192: 'remember',
#  193: 'fuck',
#  194: 'lot',
#  195: 'kill',
#  196: 'dead',
#  197: 'understand',
#  198: 'course',
#  199: 'wait',
#  200: 'guess',
#  201: 'wrong',
#  202: 'made',
#  203: 'might',
#  204: 'leave',
#  205: 'thank',
#  206: 'girl',
#  207: 'three',
#  208: 'ask',
#  209: 'getting',
#  210: 'ai',
#  211: 'happened',
#  212: 'every',
#  213: 'hear',
#  214: 'stop',
#  215: 'wanted',
#  216: 'listen',
#  217: 'real',
#  218: 'nice',
#  219: 'enough',
#  220: 'else',
#  221: 'through',
#  222: 'gotta',
#  223: 'fine',
#  224: 'done',
#  225: 'house',
#  226: 'yourself',
#  227: 'mind',
#  228: 'another',
#  229: 'someone',
#  230: 'own',
#  231: 'huh',
#  232: 'came',
#  233: 'stay',
#  234: 'trying',
#  235: 'left',
#  236: 'being',
#  237: 'uh',
#  238: 'coming',
#  239: 'care',
#  240: 'job',
#  241: 'saw',
#  242: 'father',
#  243: 'looking',
#  244: 'world',
#  245: 'knew',
#  246: 'car',
#  247: 'try',
#  248: 'went',
#  249: 'guys',
#  250: 'thanks',
#  251: 'boy',
#  252: 'room',
#  253: 'same',
#  254: 'heard',
#  255: 'mother',
#  256: 'which',
#  257: 'seen',
#  258: 'may',
#  259: 'whole',
#  260: 'show',
#  261: 'tonight',
#  262: 'friend',
#  263: 'best',
#  264: 'live',
#  265: 'used',
#  266: 'pretty',
#  267: 'matter',
#  268: "'em",
#  269: 'ya',
#  270: 'next',
#  271: 'killed',
#  272: 'business',
#  273: 'idea',
#  274: 'many',
#  275: 'morning',
#  276: 'miss',
#  277: 'found',
#  278: 'says',
#  279: 'saying',
#  280: 'called',
#  281: 'once',
#  282: 'without',
#  283: 'five',
#  284: 'myself',
#  285: 'while',
#  286: 'run',
#  287: 'head',
#  288: 'men',
#  289: 'tomorrow',
#  290: 'few',
#  291: 'most',
#  292: 'woman',
#  293: 'yet',
#  294: 'hello',
#  295: 'since',
#  296: 'start',
#  297: 'stuff',
#  298: 'together',
#  299: 'use',
#  300: 'play',
#  301: 'wife',
#  302: 'already',
#  303: 'hundred',
#  304: 'ago',
#  305: 'took',
#  306: "who's",
#  307: 'days',
#  308: 'probably',
#  309: 'until',
#  310: 'baby',
#  311: 'alone',
#  312: 'meet',
#  313: 'thinking',
#  314: 'minute',
#  315: 'hard',
#  316: 'wants',
#  317: 'school',
#  318: 'son',
#  319: 'such',
#  320: 'gone',
#  321: 'today',
#  322: 'kid',
#  323: 'crazy',
#  324: 'four',
#  325: 'anyway',
#  326: 'problem',
#  327: 'case',
#  328: 'friends',
#  329: 'dad',
#  330: 'ten',
#  331: 'damn',
#  332: 'deal',
#  333: 'point',
#  334: 'jesus',
#  335: 'afraid',
#  336: 'forget',
#  337: 'hi',
#  338: 'hope',
#  339: 'looks',
#  340: 'part',
#  341: 'die',
#  342: 'anyone',
#  343: 'exactly',
#  344: 'knows',
#  345: 'somebody',
#  346: 'supposed',
#  347: 'worry',
#  348: 'working',
#  349: 'read',
#  350: 'wanna',
#  351: 'minutes',
#  352: 'hold',
#  353: 'mrs',
#  354: 'makes',
#  355: 'bring',
#  356: 'face',
#  357: 'shut',
#  358: 'word',
#  359: 'story',
#  360: 'true',
#  361: 'happen',
#  362: 'watch',
#  363: 'nobody',
#  364: 'ass',
#  365: 'doctor',
#  366: 'move',
#  367: 'under',
#  368: 'family',
#  369: 'lost',
#  370: 'having',
#  371: 'hurt',
#  372: 'kids',
#  373: 'six',
#  374: 'turn',
#  375: 'ready',
#  376: 'both',
#  377: 'gave',
#  378: 'open',
#  379: 'married',
#  380: 'week',
#  381: 'late',
#  382: 'happy',
#  383: 'pay',
#  384: 'end',
#  385: 'john',
#  386: 'year',
#  387: 'far',
#  388: 'actually',
#  389: 'beautiful',
#  390: 'least',
#  391: 'town',
#  392: 'sleep',
#  393: 'easy',
#  394: 'taking',
#  395: 'thousand',
#  396: 'alright',
#  397: 'drink',
#  398: 'dr',
#  399: 'sit',
#  400: 'telling',
#  401: 'soon',
#  402: 'mom',
#  403: 'times',
#  404: 'gets',
#  405: 'making',
#  406: 'hit',
#  407: 'half',
#  408: 'different',
#  409: 'cut',
#  410: 'trouble',
#  411: 'door',
#  412: 'young',
#  413: 'hate',
#  414: 'brother',
#  415: 'asked',
#  416: 'each',
#  417: 'chance',
#  418: 'rest',
#  419: 'whatever',
#  420: 'jack',
#  421: 'eat',
#  422: 'anybody',
#  423: 'hand',
#  424: 'death',
#  425: 'shot',
#  426: 'question',
#  427: 'police',
#  428: 'set',
#  429: 'quite',
#  430: 'second',
#  431: 'everybody',
#  432: 'phone',
#  433: 'later',
#  434: 'wish',
#  435: 'mine',
#  436: 'change',
#  437: 'walk',
#  438: 'close',
#  439: 'couple',
#  440: 'hours',
#  441: 'check',
#  442: 'anymore',
#  443: 'comes',
#  444: 'dollars',
#  445: 'met',
#  446: 'important',
#  447: 'yours',
#  448: 'trust',
#  449: 'side',
#  450: 'captain',
#  451: 'truth',
#  452: 'sometimes',
#  453: 'heart',
#  454: 'goes',
#  455: 'funny',
#  456: 'eyes',
#  457: 'person',
#  458: 'gun',
#  459: 'its',
#  460: 'waiting',
#  461: 'honey',
#  462: 'either',
#  463: 'tried',
#  464: 'reason',
#  465: 'war',
#  466: 'bit',
#  467: 'means',
#  468: 'against',
#  469: 'suppose',
#  470: 'inside',
#  471: 'buy',
#  472: 'bed',
#  473: 'stand',
#  474: 'number',
#  475: 'excuse',
#  476: 'everyone',
#  477: 'though',
#  478: 'bet',
#  479: 'game',
#  480: 'sick',
#  481: 'break',
#  482: 'party',
#  483: 'ok',
#  484: 'almost',
#  485: 'office',
#  486: 'white',
#  487: 'sort',
#  488: 'answer',
#  489: 'water',
#  490: 'behind',
#  491: 'body',
#  492: 'running',
#  493: 'fire',
#  494: 'send',
#  495: 'women',
#  496: 'along',
#  497: 'feeling',
#  498: 'alive',
#  499: 'book',
#  500: 'twenty',
#  501: 'country',
#  502: 'died',
#  503: 'blood',
#  504: 'high',
#  505: 'pick',
#  506: 'living',
#  507: 'black',
#  508: 'ah',
#  509: 'goddamn',
#  510: 'stupid',
#  511: 'started',
#  512: 'months',
#  513: 'hands',
#  514: 'between',
#  515: 'fact',
#  516: 'power',
#  517: 'million',
#  518: 'seems',
#  519: 'figure',
#  520: 'sense',
#  521: 'drive',
#  522: 'line',
#  523: 'city',
#  524: 'boys',
#  525: 'himself',
#  526: 'serious',
#  527: 'george',
#  528: 'speak',
#  529: 'also',
#  530: 'daddy',
#  531: 'shoot',
#  532: 'hour',
#  533: 'fight',
#  534: 'christ',
#  535: 'full',
#  536: 'seem',
#  537: 'dear',
#  538: 'dinner',
#  539: 'street',
#  540: 'husband',
#  541: 'scared',
#  542: 'ahead',
#  543: 'perhaps',
#  544: 'asking',
#  545: 'able',
#  546: 'news',
#  547: 'sent',
#  548: 'front',
#  549: "'cause",
#  550: 'brought',
#  551: 'children',
#  552: 'fun',
#  553: 'ship',
#  554: 'moment',
#  555: 'free',
#  556: 'happens',
#  557: 'write',
#  558: 'safe',
#  559: 'bullshit',
#  560: 'frank',
#  561: 'outside',
#  562: 'sounds',
#  563: 'lady',
#  564: 'glad',
#  565: 'sound',
#  566: 'lose',
#  567: 'light',
#  568: 'somewhere',
#  569: 'dog',
#  570: 'girls',
#  571: 'lives',
#  572: 'ang',
#  573: 'hot',
#  574: 'promise',
#  575: 'cause',
#  576: 'bill',
#  577: 'president',
#  578: 'poor',
#  579: 'taken',
#  580: 'cool',
#  581: 'save',
#  582: 'shall',
#  583: 'weeks',
#  584: 'york',
#  585: 'beat',
#  586: 'needs',
#  587: 'child',
#  588: 'movie',
#  589: 'eight',
#  590: 'sister',
#  591: 'plan',
#  592: 'possible',
#  593: 'leaving',
#  594: 'till',
#  595: 'cold',
#  596: 'playing',
#  597: 'worth',
#  598: 'piece',
#  599: 'sex',
#  600: 'lie',
#  601: 'fifty',
#  602: "here's",
#  603: 'human',
#  604: 'pull',
#  605: 'looked',
#  606: 'small',
#  607: 'fast',
#  608: 'tired',
#  609: 'picture',
#  610: 'calling',
#  611: 'kidding',
#  612: 'words',
#  613: 'wonderful',
#  614: 'lucky',
#  615: 'thinks',
#  616: 'daughter',
#  617: 'air',
#  618: 'straight',
#  619: 'touch',
#  620: 'known',
#  621: 'hair',
#  622: 'harry',
#  623: 'special',
#  624: 'clear',
#  625: 'food',
#  626: 'company',
#  627: 'king',
#  628: 'control',
#  629: 'worked',
#  630: 'rather',
#  631: 'learn',
#  632: 'expect',
#  633: 'dream',
#  634: 'luck',
#  635: 'questions',
#  636: 'catch',
#  637: 'act',
#  638: 'order',
#  639: 'miles',
#  640: 'bitch',
#  641: 'none',
#  642: 'ride',
#  643: 'follow',
#  644: 'hospital',
#  645: 'mister',
#  646: 'state',
#  647: 'except',
#  648: 'mouth',
#  649: 'takes',
#  650: 'seeing',
#  651: 'giving',
#  652: 'coffee',
#  653: 'works',
#  654: 'mary',
#  655: 'perfect',
#  656: 'top',
#  657: 'buddy',
#  658: 'explain',
#  659: 'besides',
#  660: 'seven',
#  661: 'hotel',
#  662: "c'mon",
#  663: 'secret',
#  664: 'worse',
#  665: 'felt',
#  666: 'past',
#  667: 'accident',
#  668: 'interested',
#  669: 'general',
#  670: 'certainly',
#  671: 'wonder',
#  672: 'meeting',
#  673: 'throw',
#  674: 'parents',
#  675: 'hang',
#  676: 'unless',
#  677: 'joe',
#  678: 'drop',
#  679: 'absolutely',
#  680: 'outta',
#  681: 'loved',
#  682: 'dark',
#  683: 'red',
#  684: 'others',
#  685: 'simple',
#  686: 'date',
#  687: 'turned',
#  688: 'clean',
#  689: 'cops',
#  690: 'darling',
#  691: 'sign',
#  692: 'sam',
#  693: 'report',
#  694: 'goodbye',
#  695: 'feet',
#  696: 'less',
#  697: 'music',
#  698: 'handle',
#  699: 'information',
#  700: 'sweet',
#  701: 'tom',
#  702: 'become',
#  703: 'happening',
#  704: 'army',
#  705: 'thirty',
#  706: 'mad',
#  707: 'major',
#  708: 'talked',
#  709: 'fault',
#  710: 'caught',
#  711: 'apartment',
#  712: 'yesterday',
#  713: 'moving',
#  714: 'plane',
#  715: 'swear',
#  716: 'watching',
#  717: 'fall',
#  718: 'worried',
#  719: 'wear',
#  720: 'nine',
#  721: 'eh',
#  722: 'earth',
#  723: 'blow',
#  724: 'paid',
#  725: 'charlie',
#  726: 'law',
#  727: 'terrible',
#  728: 'sitting',
#  729: 'bank',
#  730: 'kept',
#  731: 'clothes',
#  732: 'sell',
#  733: 'david',
#  734: 'month',
#  735: 'tv',
#  736: 'mistake',
#  737: 'choice',
#  738: 'cop',
#  739: 'fucked',
#  740: 'lying',
#  741: 'strange',
#  742: 'given',
#  743: 'smart',
#  744: 'killing',
#  745: 'ones',
#  746: 'murder',
#  747: 'paper',
#  748: 'marry',
#  749: 'anywhere',
#  750: 'paul',
#  751: 'road',
#  752: 'finish',
#  753: 'hurry',
#  754: 'boss',
#  755: 'difference',
#  756: 'walter',
#  757: 'meant',
#  758: 'changed',
#  759: 'quit',
#  760: 'class',
#  761: 'figured',
#  762: 'american',
#  763: 'bob',
#  764: 'fair',
#  765: 'system',
#  766: 'early',
#  767: 'lord',
#  768: 'private',
#  769: 'rose',
#  770: 'imagine',
#  771: 'broke',
#  772: 'careful',
#  773: 'middle',
#  774: 'personal',
#  775: 'building',
#  776: 'near',
#  777: 'eye',
#  778: 'busy',
#  779: 'quiet',
#  780: 'win',
#  781: 'trip',
#  782: 'ought',
#  783: 'evening',
#  784: 'certain',
#  785: 'longer',
#  786: 'future',
#  787: 'agent',
#  788: 'record',
#  789: 'ray',
#  790: 'bucks',
#  791: 'kinda',
#  792: 'interesting',
#  793: 'store',
#  794: 'sake',
#  795: 'problems',
#  796: 'finally',
#  797: 'liked',
#  798: 'honor',
#  799: 'stick',
#  800: 'favor',
#  801: 'completely',
#  802: 'lunch',
#  803: 'blue',
#  804: 'fifteen',
#  805: 'born',
#  806: 'kiss',
#  807: 'michael',
#  808: 'boat',
#  809: 'involved',
#  810: 'respect',
#  811: 'mama',
#  812: 'tough',
#  813: 'history',
#  814: 'jimmy',
#  815: 'rich',
#  816: 'peter',
#  817: 'chief',
#  818: 'honest',
#  819: 'welcome',
#  820: 'situation',
#  821: 'ben',
#  822: 'twelve',
#  823: 'drunk',
#  824: 'wake',
#  825: 'calls',
#  826: 'spend',
#  827: 'uncle',
#  828: 'brain',
#  829: 'dude',
#  830: 'land',
#  831: 'floor',
#  832: 'offer',
#  833: 'dance',
#  834: 'jail',
#  835: 'fool',
#  836: "o'clock",
#  837: 'weird',
#  838: 'needed',
#  839: 'court',
#  840: 'officer',
#  841: 'dick',
#  842: 'realize',
#  843: 'service',
#  844: 'relax',
#  845: 'radio',
#  846: 'grand',
#  847: 'nick',
#  848: 'cash',
#  849: 'staying',
#  850: 'stopped',
#  851: 'james',
#  852: 'jim',
#  853: 'message',
#  854: 'dangerous',
#  855: 'upset',
#  856: 'driving',
#  857: 'pain',
#  858: 'books',
#  859: 'nervous',
#  860: 'english',
#  861: 'max',
#  862: 'security',
#  863: 'dying',
#  864: 'instead',
#  865: 'picked',
#  866: 'bag',
#  867: 'letter',
#  868: 'likes',
#  869: 'window',
#  870: 'bought',
#  871: 'machine',
#  872: 'afternoon',
#  873: 'ha',
#  874: 'across',
#  875: 'pass',
#  876: 'forgive',
#  877: 'putting',
#  878: 'uhhuh',
#  879: 'asshole',
#  880: 'gotten',
#  881: 'deep',
#  882: 'totally',
#  883: 'finished',
#  884: 'ran',
#  885: 'wrote',
#  886: 'lived',
#  887: 'key',
#  888: 'johnny',
#  889: 'owe',
#  890: 'decided',
#  891: 'bastard',
#  892: 'standing',
#  893: 'mangs',
#  894: 'table',
#  895: 'wearing',
#  896: 'evil',
#  897: 'bother',
#  898: 'ring',
#  899: "ma'am",
#  900: 'named',
#  901: 'fear',
#  902: 'ii',
#  903: 'eddie',
#  904: 'killer',
#  905: 'step',
#  906: 'pictures',
#  907: 'third',
#  908: 'lawyer',
#  909: 'tape',
#  910: 'voice',
#  911: 'fix',
#  912: 'missing',
#  913: 'forgot',
#  914: 'attack',
#  915: 'neither',
#  916: 'list',
#  917: 'quick',
#  918: 'strong',
#  919: 'ice',
#  920: 'doubt',
#  921: 'jake',
#  922: 'walking',
#  923: 'hungry',
#  924: 'carry',
#  925: 'bunch',
#  926: 'college',
#  927: 'age',
#  928: 'count',
#  929: 'wow',
#  930: 'return',
#  931: 'space',
#  932: 'suit',
#  933: 'fly',
#  934: 'team',
#  935: 'listening',
#  936: 'station',
#  937: 'hardly',
#  938: 'prove',
#  939: 'calm',
#  940: 'short',
#  941: 'la',
#  942: 'charge',
#  943: 'prison',
#  944: 'public',
#  945: 'join',
#  946: 'christmas',
#  947: 'slow',
#  948: 'appreciate',
#  949: 'pleasure',
#  950: 'missed',
#  951: 'surprise',
#  952: 'church',
#  953: 'island',
#  954: 'present',
#  955: 'force',
#  956: 'club',
#  957: 'starting',
#  958: 'bar',
#  959: 'moved',
#  960: 'reach',
#  961: 'truck',
#  962: 'joke',
#  963: 'saved',
#  964: 'lots',
#  965: 'computer',
#  966: 'french',
#  967: 'price',
#  968: 'lead',
#  969: 'dress',
#  970: 'gold',
#  971: 'cost',
#  972: 'cover',
#  973: 'seconds',
#  974: 'um',
#  975: 'usually',
#  976: 'fish',
#  977: 'beginning',
#  978: 'holy',
#  979: 'movies',
#  980: 'ma',
#  981: 'beer',
#  982: 'reading',
#  983: 'gives',
#  984: 'papers',
#  985: 'train',
#  986: 'box',
#  987: "one's",
#  988: 'government',
#  989: 'mark',
#  990: 'stuck',
#  991: 'smell',
#  992: 'board',
#  993: 'department',
#  994: 'art',
#  995: 'interest',
#  996: 'dreams',
#  997: 'using',
#  998: 'entire',
#  999: 'ways',
#  1000: 'teach',
#  ...}

# %%
word2index = {}
for k, v in index2word.items():
    word2index[v] = k

# %%
len(word2index) == len(index2word)
# Out:
# True

# %%
len(index2word)
# Out:
# 14999

# %% [markdown]
# ### 2-3. ONE-HOT VECTORIZER

# %%
# 単語のシーケンスを作る np.arrayにする
encoder_sequences = tokenizer.texts_to_sequences(encoder_text)
# encider_sequences = np.array(encider_sequences)

# %%
# デコーダーデータ
decoder_sequences = tokenizer.texts_to_sequences(decoder_text)
# decoder_sequences = np.array(decoder_sequences)

# %%
encoder_sequences[:5]
# Out:
# [[40, 3, 436, 28, 621],
#  [4, 950, 3],
#  [10, 27, 8, 4, 27, 1107, 802],
#  [3, 5, 186, 168],
#  [662, 4, 22, 346, 6, 130, 3, 5, 2407]]

# %%
decoder_sequences
m = 0
for seq in decoder_sequences:
    if len(seq)>m:
        m=len(seq)
print(m)
# Out:
# 358

# %%
for seqs in encoder_sequences:
    for seq in seqs:
        if seq > 14999:
            print(seq)
            break

# %%
VOCAB_SIZE = len(index2word) + 1
VOCAB_SIZE
# Out:
# 15000

# %%
import numpy as np
MAX_LEN = 20
num_samples = len(encoder_sequences)
decoder_output_data = np.zeros((num_samples, MAX_LEN, VOCAB_SIZE), dtype="float32")

# %%
# outputの３Dテンソル
for i, seqs in enumerate(decoder_sequences):
    for j, seq in enumerate(seqs):
        if j > 0:
            decoder_output_data[i][j][seq] = 1.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-1c4ab571586c> in <module>
#       3     for j, seq in enumerate(seqs):
#       4         if j > 0:
# ----> 5             decoder_output_data[i][j][seq] = 1.
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
decoder_output_data.shape

# %% [markdown]
# ### 2-4. PADDING

# %%
from keras.preprocessing.sequence import pad_sequences
encoder_input_data = pad_sequences(encoder_sequences, maxlen=MAX_LEN, dtype='int32', padding='post', truncating='post')
decoder_input_data = pad_sequences(decoder_sequences, maxlen=MAX_LEN, dtype='int32', padding='post', truncating='post')

# %%
decoder_input_data[0]

# %% [markdown]
# ### 2-5. Word2Vec: pretrained glove vector

# %%
embeddings_index = {}
with open('glove.6B.50d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()

print("Glove Loded!")

# %%
embedding_dimention = 50
def embedding_matrix_creater(embedding_dimention, word_index):
    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dimention))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
          # words not found in embedding index will be all-zeros.
            embedding_matrix[i] = embedding_vector
    return embedding_matrix

# %%
embedding_matrix = embedding_matrix_creater(50, word_index=word2index)

# %%
embed_layer = Embedding(input_dim=VOCAB_SIZE, output_dim=50, trainable=True,)
embed_layer.build((None,))
embed_layer.set_weights([embedding_matrix])

# %% [markdown]
# ## Step 3. Build Seq2Seq Model

# %%
from keras.layers import Embedding
from keras.layers import Input, Dense, LSTM, TimeDistributed
from keras.models import Model

# %%
def seq2seq_model_builder(HIDDEN_DIM=300):
    
    encoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
    encoder_embedding = embed_layer(encoder_inputs)
    encoder_LSTM = LSTM(HIDDEN_DIM, return_state=True)
    encoder_outputs, state_h, state_c = encoder_LSTM(encoder_embedding)
    
    decoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
    decoder_embedding = embed_layer(decoder_inputs)
    decoder_LSTM = LSTM(HIDDEN_DIM, return_state=True, return_sequences=True)
    decoder_outputs, _, _ = decoder_LSTM(decoder_embedding, initial_state=[state_h, state_c])
    
    # dense_layer = Dense(VOCAB_SIZE, activation='softmax')
    outputs = TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'))(decoder_outputs)
    model = Model([encoder_inputs, decoder_inputs], outputs)
    
    return model

# %%
model = seq2seq_model_builder(HIDDEN_DIM=300)

# %%
model.summary()

# %%
model.compile(optimizer='adam', loss ='categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Step 4. Training Model

# %%
BATCH_SIZE = 32
EPOCHS = 5

# %%
encoder_input_data.shape

# %%
from sklearn.model_selection import train_test_split
en_train, en_val, ja_train, ja_val = train_test_split(encoder_input_data, decoder_input_data)

# %%
train_num = len(en_train)
target_train = decoder_output_data[:train_num]
target_val = decoder_output_data[train_num:]

# %%
history = model.fit([en_train, ja_train], 
                     target_train, 
                     epochs=EPOCHS, 
                     batch_size=BATCH_SIZE,
                     validation_data=([en_val, ja_val], target_val))

# %% [markdown]
# #### Visualize Learning History

# %%
# 正確性の可視化
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10, 6))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# 損失関数の可視化
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# 重みを保存する
json_string = model.to_json()
open('seq2seq.json', 'w').write(json_string)
model.save_weights('seq2seq_weights.h5')

# %%
# %ls

# %%
pwd

# %% [markdown]
# ## Step 5. Inference

# %%
json_file = open('seq2seq.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
chat_model = model.from_json(loaded_model_json)

# load weights into new model
chat_model.load_weights("model.h5")

# %%
ball = "I am Hungry. What do you suggest?"

# %%
import re
cleaned_ball = clean_text(ball)

# %%
query = cleaned_ball.split()
query = np.array([word2index[word] for word in query])
query = pad_sequences([query], maxlen=20)

# %%
encoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
encoder_embedding = embed_layer(encoder_inputs)
# encoder_LSTM = LSTM(HIDDEN_DIM, return_state=True)
encoder_outputs, state_h, state_c = encoder_LSTM(encoder_embedding)

decoder_inputs = Input(shape=(MAX_LEN, ), dtype='int32',)
decoder_embedding = embed_layer(decoder_inputs)
# decoder_LSTM = LSTM(HIDDEN_DIM, return_state=True, return_sequences=True)
decoder_outputs, _h, _c = decoder_LSTM(decoder_embedding, initial_state=[state_h, state_c])

# dense_layer = Dense(VOCAB_SIZE, activation='softmax')
outputs = TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'))(decoder_outputs)

chat_model = Model(encoder_inputs, [state_h, state_c])

# %%
# define the inputs for the decoder LSTM
h = Input(shape = (300, ))
c = Input(shape = (300, ))

# %%
_outputs, _h, _c = decoder_LSTM(decoder_embedding, initial_state=[h, c])
outputs = TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'))(_outputs)
chat_model = Model([encoder_inputs, state_h, state_c], [outputs, _h, _c])

# %%
# pass in the question to the encoder LSTM, to get the final encoder states of the encoder LSTM
query_h, query_c = chat_model.predict(query)

# %%
# initialize the answer that will be generated for the 'BOS' input. Since we have used pre-padding for padding sequences,
# the last token in the 'answer' variable is initialised with the index for 'BOS'.
answer = np.zeros((1, MAX_LEN))
answer[0, -1] = word2index['<BOS >']

# %%
# i keeps track of the length of the generated answer. This won't allow the model to genrate sequences with more than 20 words.
i = 1

# make a new list to store the words generated at each time step
answer_1 = []

# flag to stop the model when 'EOS' tag is generated or when 20 time steps have passed.
flag = 0

# run the inference model
while flag != 1:
    # make predictions for the given input token and encoder states
    prediction, prediction_h, prediction_c = chat_model.predict([answer, query_h, query_c])
    
    # from the generated predictions of shape (num_examples, maxLen, vocab_size), find the token with max probability
    token_arg = np.argmax(prediction[0, -1, :])
    
    # append the corresponding word of the index to the answer_1 list
    answer_1.append(index2word[token_arg])
    
    # set flag to 1 if 'EOS' token is generated or 20 time steps have passed
    if token_arg == word2index[' <EOS>'] or i > 20:
        flag = 1
    # re-initialise the answer variable, and set the last token to the output of the current time step. This is then passed
    # as input to the next time step, along with the LSTM states of the current time step
    answer = np.zeros((1, MAX_LEN))
    answer[0, -1] = token_arg
    query_h = prediction_h
    query_c = prediction_c
    
    # increment the count of the loop
    i += 1
    
 # print the answer generated for the given question
print (" ".join(answer_1))
